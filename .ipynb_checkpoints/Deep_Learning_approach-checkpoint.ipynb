# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import os
import datetime as dt
import matplotlib.dates as mdates
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, r2_score

# %%
from keras.models import Sequential
from keras.layers import Dropout, Dense
from sklearn.utils import shuffle
import sys
import talos
# Out:
# Using TensorFlow backend.
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Changes the font parameters for the charts
params = {'legend.fontsize': 14,
         'axes.labelsize': 16,
         'axes.titlesize': 16,
         'xtick.labelsize': 10,
         'ytick.labelsize': 10}
plt.rcParams.update(params)

# %%
params = {}

# %%
## Change to the 'Datasets directory'
gold_col = 'GOLDAMGBDollarD228NLBM' # 'GOLD_shift' 
initial_dir = os.getcwd()
data_path = os.path.join(os.getcwd(), "data")

# %%
hml_list = ['high', 'mid', 'low']

# %%
for i in hml_list:

    ## Import the train and test dataframes. Drop the 'dateRep' column as it is not need for the prediciton.
    train_X = pd.read_csv(os.path.join(data_path, "train", 'train_x_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)
    train_y = pd.read_csv(os.path.join(data_path, "train", 'train_y_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)
    ## '.sample' randomises the dataframe as the validation test below will take the bottom 20% of the data
    ## 'frac=1' means it will use all the data and 'random_state=1' keeps the resample consistent between df's
    test_x = pd.read_csv(os.path.join(data_path, "test", 'test_x_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)
    test_y = pd.read_csv(os.path.join(data_path, "test", 'test_y_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)

    ## Initialise Scalars so that data is normalised to 1.
    sc_x = StandardScaler()
    sc_y = StandardScaler()
    ## Normalise the data using the scalar.
    X_train = sc_x.fit_transform(train_X)
    X_test = sc_x.transform(test_x)

    y_train = sc_y.fit_transform(train_y)
    y_test = sc_y.transform(test_y)
    
    
    ## Calculate the number of input 'test' columns.
    input_neuron = len(test_x.columns)
    
    ## Setup the model for training, parameters here can and should be adjusted to create the best model.
    classifier = Sequential()
    classifier.add(Dense(output_dim = 18, init = 'uniform', activation = 'relu', input_dim = input_neuron))
    classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu'))
    classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'linear'))

    classifier.compile(optimizer = 'SGD', loss = 'mean_squared_error', metrics = ["mae"])
    ## '.fit' starts the training. 30 seconds to 2 minutes to run.
    classifier.fit(X_train, y_train, batch_size = 32, nb_epoch = 1000, validation_split= 0.2)


    model_path = os.path.join(os.getcwd(), "model")
    # Check if the relevant folders exist and create them if not
    if os.path.exists(model_path) is False:
        os.mkdir(model_path)
    # Export the model for future use to that you don't need to spend time training the model again
    pickle.dump(classifier, open(os.path.join(model_path, "ReinNN_" + i + ".pkl"), "wb"))
# Out:
# Train on 451 samples, validate on 113 samples
# Epoch 1/1000
# 451/451 [==============================] - 0s 638us/step - loss: 0.9842 - mae: 0.7214 - val_loss: 1.0620 - val_mae: 0.7280
# Epoch 2/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.9839 - mae: 0.7139 - val_loss: 1.0624 - val_mae: 0.7382
# Epoch 3/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.9835 - mae: 0.7235 - val_loss: 1.0619 - val_mae: 0.7344
# Epoch 4/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.9836 - mae: 0.7212 - val_loss: 1.0617 - val_mae: 0.7329
# Epoch 5/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.9834 - mae: 0.7212 - val_loss: 1.0614 - val_mae: 0.7299
# Epoch 6/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.9835 - mae: 0.7159 - val_loss: 1.0616 - val_mae: 0.7376
# Epoch 7/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.9829 - mae: 0.7241 - val_loss: 1.0618 - val_mae: 0.7414
# Epoch 8/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.9828 - mae: 0.7287 - val_loss: 1.0609 - val_mae: 0.7339
# Epoch 9/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.9824 - mae: 0.7195 - val_loss: 1.0609 - val_mae: 0.7380
# Epoch 10/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.9824 - mae: 0.7222 - val_loss: 1.0610 - val_mae: 0.7427
# Epoch 11/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.9820 - mae: 0.7288 - val_loss: 1.0599 - val_mae: 0.7369
# Epoch 12/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.9811 - mae: 0.7248 - val_loss: 1.0592 - val_mae: 0.7328
# Epoch 13/1000
# 451/451 [==============================] - 0s 47us/step - loss: 0.9807 - mae: 0.7204 - val_loss: 1.0585 - val_mae: 0.7304
# Epoch 14/1000
# 451/451 [==============================] - 0s 47us/step - loss: 0.9799 - mae: 0.7163 - val_loss: 1.0582 - val_mae: 0.7380
# Epoch 15/1000
# 451/451 [==============================] - 0s 47us/step - loss: 0.9790 - mae: 0.7236 - val_loss: 1.0574 - val_mae: 0.7386
# Epoch 16/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.9779 - mae: 0.7233 - val_loss: 1.0562 - val_mae: 0.7368
# Epoch 17/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.9768 - mae: 0.7252 - val_loss: 1.0545 - val_mae: 0.7302
# Epoch 18/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.9753 - mae: 0.7195 - val_loss: 1.0529 - val_mae: 0.7245
# Epoch 19/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.9738 - mae: 0.7115 - val_loss: 1.0510 - val_mae: 0.7205
# Epoch 20/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.9714 - mae: 0.7075 - val_loss: 1.0486 - val_mae: 0.7203
# Epoch 21/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.9687 - mae: 0.7063 - val_loss: 1.0454 - val_mae: 0.7264
# Epoch 22/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.9643 - mae: 0.7144 - val_loss: 1.0415 - val_mae: 0.7239
# Epoch 23/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.9598 - mae: 0.7098 - val_loss: 1.0363 - val_mae: 0.7188
# Epoch 24/1000
# 451/451 [==============================] - 0s 47us/step - loss: 0.9534 - mae: 0.7048 - val_loss: 1.0294 - val_mae: 0.7166
# Epoch 25/1000
# 451/451 [==============================] - 0s 47us/step - loss: 0.9450 - mae: 0.7014 - val_loss: 1.0184 - val_mae: 0.7237
# Epoch 26/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.9312 - mae: 0.7090 - val_loss: 1.0045 - val_mae: 0.7146
# Epoch 27/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.9137 - mae: 0.6989 - val_loss: 0.9822 - val_mae: 0.7082
# Epoch 28/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.8862 - mae: 0.6900 - val_loss: 0.9527 - val_mae: 0.6926
# Epoch 29/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.8479 - mae: 0.6754 - val_loss: 0.9087 - val_mae: 0.6762
# Epoch 30/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.7919 - mae: 0.6530 - val_loss: 0.8305 - val_mae: 0.6639
# Epoch 31/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.6970 - mae: 0.6283 - val_loss: 0.7000 - val_mae: 0.6405
# Epoch 32/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.5553 - mae: 0.5932 - val_loss: 0.5753 - val_mae: 0.5826
# Epoch 33/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.4359 - mae: 0.5286 - val_loss: 0.4565 - val_mae: 0.5244
# Epoch 34/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.3425 - mae: 0.4676 - val_loss: 0.3642 - val_mae: 0.4623
# Epoch 35/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.2741 - mae: 0.4135 - val_loss: 0.3100 - val_mae: 0.4210
# Epoch 36/1000
# 451/451 [==============================] - 0s 47us/step - loss: 0.2334 - mae: 0.3782 - val_loss: 0.2645 - val_mae: 0.3920
# Epoch 37/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.2067 - mae: 0.3572 - val_loss: 0.2447 - val_mae: 0.3803
# Epoch 38/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.1911 - mae: 0.3451 - val_loss: 0.2250 - val_mae: 0.3700
# Epoch 39/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.1802 - mae: 0.3370 - val_loss: 0.2095 - val_mae: 0.3628
# Epoch 40/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.1719 - mae: 0.3324 - val_loss: 0.2006 - val_mae: 0.3583
# Epoch 41/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1678 - mae: 0.3297 - val_loss: 0.1978 - val_mae: 0.3570
# Epoch 42/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1647 - mae: 0.3290 - val_loss: 0.2007 - val_mae: 0.3584
# Epoch 43/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1617 - mae: 0.3258 - val_loss: 0.1901 - val_mae: 0.3526
# Epoch 44/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.1589 - mae: 0.3247 - val_loss: 0.1976 - val_mae: 0.3555
# Epoch 45/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1559 - mae: 0.3204 - val_loss: 0.1739 - val_mae: 0.3424
# Epoch 46/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1537 - mae: 0.3217 - val_loss: 0.1878 - val_mae: 0.3487
# Epoch 47/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1499 - mae: 0.3161 - val_loss: 0.1927 - val_mae: 0.3506
# Epoch 48/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1487 - mae: 0.3127 - val_loss: 0.1892 - val_mae: 0.3486
# Epoch 49/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1470 - mae: 0.3114 - val_loss: 0.1768 - val_mae: 0.3413
# Epoch 50/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.1451 - mae: 0.3107 - val_loss: 0.1676 - val_mae: 0.3358
# Epoch 51/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1449 - mae: 0.3125 - val_loss: 0.1778 - val_mae: 0.3411
# Epoch 52/1000
# 451/451 [==============================] - 0s 52us/step - loss: 0.1423 - mae: 0.3079 - val_loss: 0.1774 - val_mae: 0.3394
# Epoch 53/1000
# 451/451 [==============================] - 0s 48us/step - loss: 0.1404 - mae: 0.3052 - val_loss: 0.1851 - val_mae: 0.3428
# Epoch 54/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.1395 - mae: 0.3013 - val_loss: 0.1792 - val_mae: 0.3391
# Epoch 55/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.1376 - mae: 0.2993 - val_loss: 0.1785 - val_mae: 0.3380
# Epoch 56/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.1372 - mae: 0.2989 - val_loss: 0.1742 - val_mae: 0.3354
# Epoch 57/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.1354 - mae: 0.2959 - val_loss: 0.1670 - val_mae: 0.3312
# Epoch 58/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.1343 - mae: 0.2973 - val_loss: 0.1666 - val_mae: 0.3304
# Epoch 59/1000
# 451/451 [==============================] - 0s 47us/step - loss: 0.1335 - mae: 0.2964 - val_loss: 0.1680 - val_mae: 0.3305
# Epoch 60/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.1314 - mae: 0.2914 - val_loss: 0.1520 - val_mae: 0.3238
# Epoch 61/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.1326 - mae: 0.2974 - val_loss: 0.1735 - val_mae: 0.3320
# Epoch 62/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.1296 - mae: 0.2869 - val_loss: 0.1657 - val_mae: 0.3274
# Epoch 63/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.1288 - mae: 0.2885 - val_loss: 0.1644 - val_mae: 0.3262
# Epoch 64/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.1274 - mae: 0.2870 - val_loss: 0.1562 - val_mae: 0.3219
# Epoch 65/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1265 - mae: 0.2878 - val_loss: 0.1742 - val_mae: 0.3298
# Epoch 66/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1262 - mae: 0.2811 - val_loss: 0.1626 - val_mae: 0.3233
# Epoch 67/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.1240 - mae: 0.2813 - val_loss: 0.1573 - val_mae: 0.3201
# Epoch 68/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1226 - mae: 0.2795 - val_loss: 0.1538 - val_mae: 0.3175
# Epoch 69/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1214 - mae: 0.2792 - val_loss: 0.1531 - val_mae: 0.3162
# Epoch 70/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1208 - mae: 0.2781 - val_loss: 0.1539 - val_mae: 0.3155
# Epoch 71/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.1192 - mae: 0.2758 - val_loss: 0.1409 - val_mae: 0.3099
# Epoch 72/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1190 - mae: 0.2797 - val_loss: 0.1509 - val_mae: 0.3120
# Epoch 73/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1174 - mae: 0.2720 - val_loss: 0.1468 - val_mae: 0.3091
# Epoch 74/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.1156 - mae: 0.2713 - val_loss: 0.1352 - val_mae: 0.3036
# Epoch 75/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1151 - mae: 0.2742 - val_loss: 0.1435 - val_mae: 0.3049
# Epoch 76/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.1132 - mae: 0.2682 - val_loss: 0.1431 - val_mae: 0.3036
# Epoch 77/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1120 - mae: 0.2668 - val_loss: 0.1528 - val_mae: 0.3067
# Epoch 78/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.1119 - mae: 0.2613 - val_loss: 0.1437 - val_mae: 0.3013
# Epoch 79/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1100 - mae: 0.2621 - val_loss: 0.1425 - val_mae: 0.2992
# Epoch 80/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1087 - mae: 0.2598 - val_loss: 0.1401 - val_mae: 0.2966
# Epoch 81/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.1072 - mae: 0.2582 - val_loss: 0.1354 - val_mae: 0.2927
# Epoch 82/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1057 - mae: 0.2548 - val_loss: 0.1288 - val_mae: 0.2888
# Epoch 83/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.1045 - mae: 0.2570 - val_loss: 0.1354 - val_mae: 0.2895
# Epoch 84/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1035 - mae: 0.2521 - val_loss: 0.1289 - val_mae: 0.2849
# Epoch 85/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.1018 - mae: 0.2524 - val_loss: 0.1290 - val_mae: 0.2834
# Epoch 86/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.1007 - mae: 0.2499 - val_loss: 0.1279 - val_mae: 0.2813
# Epoch 87/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0998 - mae: 0.2485 - val_loss: 0.1250 - val_mae: 0.2781
# Epoch 88/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0981 - mae: 0.2460 - val_loss: 0.1264 - val_mae: 0.2773
# Epoch 89/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0972 - mae: 0.2434 - val_loss: 0.1239 - val_mae: 0.2747
# Epoch 90/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0958 - mae: 0.2423 - val_loss: 0.1294 - val_mae: 0.2760
# Epoch 91/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0951 - mae: 0.2376 - val_loss: 0.1176 - val_mae: 0.2677
# Epoch 92/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0933 - mae: 0.2389 - val_loss: 0.1145 - val_mae: 0.2643
# Epoch 93/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0917 - mae: 0.2358 - val_loss: 0.1101 - val_mae: 0.2607
# Epoch 94/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0909 - mae: 0.2360 - val_loss: 0.1106 - val_mae: 0.2592
# Epoch 95/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0892 - mae: 0.2325 - val_loss: 0.1085 - val_mae: 0.2565
# Epoch 96/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0882 - mae: 0.2314 - val_loss: 0.1192 - val_mae: 0.2604
# Epoch 97/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0880 - mae: 0.2265 - val_loss: 0.1084 - val_mae: 0.2528
# Epoch 98/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0867 - mae: 0.2284 - val_loss: 0.0987 - val_mae: 0.2472
# Epoch 99/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0852 - mae: 0.2278 - val_loss: 0.1126 - val_mae: 0.2519
# Epoch 100/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0847 - mae: 0.2203 - val_loss: 0.1024 - val_mae: 0.2446
# Epoch 101/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0828 - mae: 0.2224 - val_loss: 0.0997 - val_mae: 0.2414
# Epoch 102/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0817 - mae: 0.2206 - val_loss: 0.0957 - val_mae: 0.2380
# Epoch 103/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0807 - mae: 0.2195 - val_loss: 0.0927 - val_mae: 0.2348
# Epoch 104/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0795 - mae: 0.2169 - val_loss: 0.0934 - val_mae: 0.2326
# Epoch 105/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0785 - mae: 0.2163 - val_loss: 0.0935 - val_mae: 0.2307
# Epoch 106/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0776 - mae: 0.2143 - val_loss: 0.0925 - val_mae: 0.2286
# Epoch 107/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0765 - mae: 0.2113 - val_loss: 0.0861 - val_mae: 0.2247
# Epoch 108/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0753 - mae: 0.2123 - val_loss: 0.0860 - val_mae: 0.2223
# Epoch 109/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0744 - mae: 0.2102 - val_loss: 0.0922 - val_mae: 0.2225
# Epoch 110/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0735 - mae: 0.2047 - val_loss: 0.0760 - val_mae: 0.2133
# Epoch 111/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0730 - mae: 0.2090 - val_loss: 0.0814 - val_mae: 0.2137
# Epoch 112/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0711 - mae: 0.2044 - val_loss: 0.0858 - val_mae: 0.2135
# Epoch 113/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0705 - mae: 0.1996 - val_loss: 0.0879 - val_mae: 0.2124
# Epoch 114/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0702 - mae: 0.1989 - val_loss: 0.0805 - val_mae: 0.2074
# Epoch 115/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0688 - mae: 0.1970 - val_loss: 0.0862 - val_mae: 0.2092
# Epoch 116/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0684 - mae: 0.1951 - val_loss: 0.0843 - val_mae: 0.2058
# Epoch 117/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0672 - mae: 0.1910 - val_loss: 0.0766 - val_mae: 0.2009
# Epoch 118/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0660 - mae: 0.1909 - val_loss: 0.0752 - val_mae: 0.1984
# Epoch 119/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0647 - mae: 0.1891 - val_loss: 0.0745 - val_mae: 0.1962
# Epoch 120/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0640 - mae: 0.1858 - val_loss: 0.0737 - val_mae: 0.1942
# Epoch 121/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0633 - mae: 0.1837 - val_loss: 0.0606 - val_mae: 0.1854
# Epoch 122/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0694 - mae: 0.1977 - val_loss: 0.0688 - val_mae: 0.1891
# Epoch 123/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0620 - mae: 0.1817 - val_loss: 0.0660 - val_mae: 0.1861
# Epoch 124/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0614 - mae: 0.1813 - val_loss: 0.0656 - val_mae: 0.1842
# Epoch 125/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0609 - mae: 0.1796 - val_loss: 0.0703 - val_mae: 0.1844
# Epoch 126/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0602 - mae: 0.1764 - val_loss: 0.0605 - val_mae: 0.1788
# Epoch 127/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0605 - mae: 0.1789 - val_loss: 0.0625 - val_mae: 0.1787
# Epoch 128/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0591 - mae: 0.1757 - val_loss: 0.0576 - val_mae: 0.1752
# Epoch 129/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0595 - mae: 0.1774 - val_loss: 0.0638 - val_mae: 0.1773
# Epoch 130/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0579 - mae: 0.1735 - val_loss: 0.0655 - val_mae: 0.1769
# Epoch 131/1000
# 451/451 [==============================] - 0s 47us/step - loss: 0.0580 - mae: 0.1712 - val_loss: 0.0726 - val_mae: 0.1783
# Epoch 132/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0581 - mae: 0.1683 - val_loss: 0.0628 - val_mae: 0.1736
# Epoch 133/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0567 - mae: 0.1705 - val_loss: 0.0651 - val_mae: 0.1735
# Epoch 134/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0569 - mae: 0.1686 - val_loss: 0.0632 - val_mae: 0.1712
# Epoch 135/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0559 - mae: 0.1678 - val_loss: 0.0657 - val_mae: 0.1714
# Epoch 136/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0556 - mae: 0.1640 - val_loss: 0.0610 - val_mae: 0.1681
# Epoch 137/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0552 - mae: 0.1649 - val_loss: 0.0591 - val_mae: 0.1664
# Epoch 138/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0547 - mae: 0.1652 - val_loss: 0.0514 - val_mae: 0.1620
# Epoch 139/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0559 - mae: 0.1677 - val_loss: 0.0570 - val_mae: 0.1640
# Epoch 140/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0540 - mae: 0.1625 - val_loss: 0.0606 - val_mae: 0.1649
# Epoch 141/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0536 - mae: 0.1611 - val_loss: 0.0623 - val_mae: 0.1650
# Epoch 142/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.0533 - mae: 0.1590 - val_loss: 0.0536 - val_mae: 0.1598
# Epoch 143/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0528 - mae: 0.1624 - val_loss: 0.0624 - val_mae: 0.1626
# Epoch 144/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0528 - mae: 0.1574 - val_loss: 0.0632 - val_mae: 0.1622
# Epoch 145/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0525 - mae: 0.1570 - val_loss: 0.0625 - val_mae: 0.1613
# Epoch 146/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0525 - mae: 0.1555 - val_loss: 0.0580 - val_mae: 0.1589
# Epoch 147/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0520 - mae: 0.1563 - val_loss: 0.0566 - val_mae: 0.1576
# Epoch 148/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0517 - mae: 0.1557 - val_loss: 0.0560 - val_mae: 0.1566
# Epoch 149/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0513 - mae: 0.1548 - val_loss: 0.0558 - val_mae: 0.1558
# Epoch 150/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0509 - mae: 0.1552 - val_loss: 0.0580 - val_mae: 0.1563
# Epoch 151/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0508 - mae: 0.1524 - val_loss: 0.0562 - val_mae: 0.1547
# Epoch 152/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0505 - mae: 0.1534 - val_loss: 0.0569 - val_mae: 0.1543
# Epoch 153/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0502 - mae: 0.1520 - val_loss: 0.0553 - val_mae: 0.1529
# Epoch 154/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0502 - mae: 0.1513 - val_loss: 0.0550 - val_mae: 0.1527
# Epoch 155/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0498 - mae: 0.1506 - val_loss: 0.0462 - val_mae: 0.1484
# Epoch 156/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0509 - mae: 0.1562 - val_loss: 0.0480 - val_mae: 0.1480
# Epoch 157/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0499 - mae: 0.1526 - val_loss: 0.0526 - val_mae: 0.1514
# Epoch 158/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0494 - mae: 0.1507 - val_loss: 0.0527 - val_mae: 0.1498
# Epoch 159/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0491 - mae: 0.1494 - val_loss: 0.0522 - val_mae: 0.1481
# Epoch 160/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0488 - mae: 0.1489 - val_loss: 0.0545 - val_mae: 0.1491
# Epoch 161/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0485 - mae: 0.1469 - val_loss: 0.0482 - val_mae: 0.1460
# Epoch 162/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0483 - mae: 0.1502 - val_loss: 0.0505 - val_mae: 0.1480
# Epoch 163/1000
# 451/451 [==============================] - 0s 49us/step - loss: 0.0485 - mae: 0.1500 - val_loss: 0.0514 - val_mae: 0.1466
# Epoch 164/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0481 - mae: 0.1477 - val_loss: 0.0509 - val_mae: 0.1451
# Epoch 165/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0475 - mae: 0.1469 - val_loss: 0.0516 - val_mae: 0.1441
# Epoch 166/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0476 - mae: 0.1450 - val_loss: 0.0425 - val_mae: 0.1435
# Epoch 167/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0490 - mae: 0.1517 - val_loss: 0.0534 - val_mae: 0.1447
# Epoch 168/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0471 - mae: 0.1428 - val_loss: 0.0506 - val_mae: 0.1421
# Epoch 169/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0468 - mae: 0.1441 - val_loss: 0.0491 - val_mae: 0.1442
# Epoch 170/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0468 - mae: 0.1458 - val_loss: 0.0494 - val_mae: 0.1414
# Epoch 171/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0466 - mae: 0.1431 - val_loss: 0.0501 - val_mae: 0.1406
# Epoch 172/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0459 - mae: 0.1401 - val_loss: 0.0415 - val_mae: 0.1395
# Epoch 173/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0481 - mae: 0.1474 - val_loss: 0.0461 - val_mae: 0.1383
# Epoch 174/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0463 - mae: 0.1420 - val_loss: 0.0488 - val_mae: 0.1386
# Epoch 175/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0460 - mae: 0.1400 - val_loss: 0.0504 - val_mae: 0.1392
# Epoch 176/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0454 - mae: 0.1389 - val_loss: 0.0529 - val_mae: 0.1403
# Epoch 177/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0454 - mae: 0.1376 - val_loss: 0.0506 - val_mae: 0.1385
# Epoch 178/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0451 - mae: 0.1375 - val_loss: 0.0486 - val_mae: 0.1368
# Epoch 179/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0450 - mae: 0.1379 - val_loss: 0.0481 - val_mae: 0.1361
# Epoch 180/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0450 - mae: 0.1376 - val_loss: 0.0429 - val_mae: 0.1346
# Epoch 181/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0448 - mae: 0.1410 - val_loss: 0.0624 - val_mae: 0.1451
# Epoch 182/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0457 - mae: 0.1337 - val_loss: 0.0485 - val_mae: 0.1348
# Epoch 183/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0448 - mae: 0.1372 - val_loss: 0.0511 - val_mae: 0.1354
# Epoch 184/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0442 - mae: 0.1339 - val_loss: 0.0463 - val_mae: 0.1342
# Epoch 185/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0443 - mae: 0.1357 - val_loss: 0.0478 - val_mae: 0.1336
# Epoch 186/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0438 - mae: 0.1338 - val_loss: 0.0454 - val_mae: 0.1324
# Epoch 187/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0439 - mae: 0.1349 - val_loss: 0.0416 - val_mae: 0.1336
# Epoch 188/1000
# 451/451 [==============================] - 0s 49us/step - loss: 0.0442 - mae: 0.1385 - val_loss: 0.0448 - val_mae: 0.1320
# Epoch 189/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.0436 - mae: 0.1351 - val_loss: 0.0472 - val_mae: 0.1318
# Epoch 190/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0433 - mae: 0.1333 - val_loss: 0.0471 - val_mae: 0.1334
# Epoch 191/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0431 - mae: 0.1348 - val_loss: 0.0445 - val_mae: 0.1306
# Epoch 192/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0428 - mae: 0.1337 - val_loss: 0.0520 - val_mae: 0.1336
# Epoch 193/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0429 - mae: 0.1305 - val_loss: 0.0381 - val_mae: 0.1318
# Epoch 194/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0449 - mae: 0.1403 - val_loss: 0.0472 - val_mae: 0.1306
# Epoch 195/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0427 - mae: 0.1306 - val_loss: 0.0444 - val_mae: 0.1292
# Epoch 196/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0426 - mae: 0.1310 - val_loss: 0.0451 - val_mae: 0.1291
# Epoch 197/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0425 - mae: 0.1308 - val_loss: 0.0488 - val_mae: 0.1307
# Epoch 198/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0423 - mae: 0.1295 - val_loss: 0.0486 - val_mae: 0.1303
# Epoch 199/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0422 - mae: 0.1303 - val_loss: 0.0479 - val_mae: 0.1294
# Epoch 200/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0423 - mae: 0.1294 - val_loss: 0.0445 - val_mae: 0.1281
# Epoch 201/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0423 - mae: 0.1307 - val_loss: 0.0441 - val_mae: 0.1276
# Epoch 202/1000
# 451/451 [==============================] - 0s 49us/step - loss: 0.0416 - mae: 0.1305 - val_loss: 0.0522 - val_mae: 0.1308
# Epoch 203/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0418 - mae: 0.1278 - val_loss: 0.0474 - val_mae: 0.1288
# Epoch 204/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0415 - mae: 0.1287 - val_loss: 0.0568 - val_mae: 0.1338
# Epoch 205/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0421 - mae: 0.1261 - val_loss: 0.0546 - val_mae: 0.1317
# Epoch 206/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0418 - mae: 0.1265 - val_loss: 0.0451 - val_mae: 0.1274
# Epoch 207/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0409 - mae: 0.1281 - val_loss: 0.0448 - val_mae: 0.1269
# Epoch 208/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0407 - mae: 0.1266 - val_loss: 0.0463 - val_mae: 0.1273
# Epoch 209/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0410 - mae: 0.1276 - val_loss: 0.0365 - val_mae: 0.1267
# Epoch 210/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0415 - mae: 0.1327 - val_loss: 0.0472 - val_mae: 0.1273
# Epoch 211/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0406 - mae: 0.1263 - val_loss: 0.0429 - val_mae: 0.1257
# Epoch 212/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0402 - mae: 0.1250 - val_loss: 0.0406 - val_mae: 0.1250
# Epoch 213/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0402 - mae: 0.1279 - val_loss: 0.0455 - val_mae: 0.1261
# Epoch 214/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0401 - mae: 0.1261 - val_loss: 0.0440 - val_mae: 0.1253
# Epoch 215/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0403 - mae: 0.1253 - val_loss: 0.0428 - val_mae: 0.1247
# Epoch 216/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0401 - mae: 0.1258 - val_loss: 0.0468 - val_mae: 0.1256
# Epoch 217/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0395 - mae: 0.1237 - val_loss: 0.0411 - val_mae: 0.1238
# Epoch 218/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0394 - mae: 0.1260 - val_loss: 0.0513 - val_mae: 0.1273
# Epoch 219/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0406 - mae: 0.1240 - val_loss: 0.0435 - val_mae: 0.1240
# Epoch 220/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0393 - mae: 0.1241 - val_loss: 0.0422 - val_mae: 0.1234
# Epoch 221/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0398 - mae: 0.1257 - val_loss: 0.0423 - val_mae: 0.1234
# Epoch 222/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0393 - mae: 0.1250 - val_loss: 0.0444 - val_mae: 0.1238
# Epoch 223/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0389 - mae: 0.1222 - val_loss: 0.0420 - val_mae: 0.1226
# Epoch 224/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0390 - mae: 0.1233 - val_loss: 0.0353 - val_mae: 0.1245
# Epoch 225/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0414 - mae: 0.1326 - val_loss: 0.0408 - val_mae: 0.1219
# Epoch 226/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0391 - mae: 0.1230 - val_loss: 0.0410 - val_mae: 0.1219
# Epoch 227/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0388 - mae: 0.1221 - val_loss: 0.0392 - val_mae: 0.1217
# Epoch 228/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0387 - mae: 0.1248 - val_loss: 0.0438 - val_mae: 0.1224
# Epoch 229/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0387 - mae: 0.1217 - val_loss: 0.0414 - val_mae: 0.1215
# Epoch 230/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0384 - mae: 0.1226 - val_loss: 0.0429 - val_mae: 0.1219
# Epoch 231/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0382 - mae: 0.1213 - val_loss: 0.0464 - val_mae: 0.1233
# Epoch 232/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0382 - mae: 0.1202 - val_loss: 0.0412 - val_mae: 0.1214
# Epoch 233/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0376 - mae: 0.1225 - val_loss: 0.0433 - val_mae: 0.1216
# Epoch 234/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0380 - mae: 0.1206 - val_loss: 0.0431 - val_mae: 0.1214
# Epoch 235/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0384 - mae: 0.1204 - val_loss: 0.0352 - val_mae: 0.1199
# Epoch 236/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0382 - mae: 0.1249 - val_loss: 0.0397 - val_mae: 0.1205
# Epoch 237/1000
# 451/451 [==============================] - 0s 48us/step - loss: 0.0377 - mae: 0.1207 - val_loss: 0.0381 - val_mae: 0.1195
# Epoch 238/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0373 - mae: 0.1227 - val_loss: 0.0410 - val_mae: 0.1204
# Epoch 239/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0373 - mae: 0.1194 - val_loss: 0.0389 - val_mae: 0.1220
# Epoch 240/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0374 - mae: 0.1224 - val_loss: 0.0402 - val_mae: 0.1204
# Epoch 241/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0369 - mae: 0.1199 - val_loss: 0.0393 - val_mae: 0.1194
# Epoch 242/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0370 - mae: 0.1214 - val_loss: 0.0490 - val_mae: 0.1230
# Epoch 243/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0376 - mae: 0.1201 - val_loss: 0.0402 - val_mae: 0.1202
# Epoch 244/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0369 - mae: 0.1200 - val_loss: 0.0377 - val_mae: 0.1199
# Epoch 245/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0368 - mae: 0.1216 - val_loss: 0.0403 - val_mae: 0.1201
# Epoch 246/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0365 - mae: 0.1198 - val_loss: 0.0405 - val_mae: 0.1198
# Epoch 247/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0364 - mae: 0.1194 - val_loss: 0.0335 - val_mae: 0.1196
# Epoch 248/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0393 - mae: 0.1265 - val_loss: 0.0373 - val_mae: 0.1181
# Epoch 249/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0364 - mae: 0.1194 - val_loss: 0.0392 - val_mae: 0.1185
# Epoch 250/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0364 - mae: 0.1191 - val_loss: 0.0406 - val_mae: 0.1187
# Epoch 251/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0359 - mae: 0.1176 - val_loss: 0.0341 - val_mae: 0.1170
# Epoch 252/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0366 - mae: 0.1208 - val_loss: 0.0378 - val_mae: 0.1177
# Epoch 253/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0359 - mae: 0.1178 - val_loss: 0.0414 - val_mae: 0.1193
# Epoch 254/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0359 - mae: 0.1184 - val_loss: 0.0485 - val_mae: 0.1226
# Epoch 255/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0362 - mae: 0.1165 - val_loss: 0.0366 - val_mae: 0.1176
# Epoch 256/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0355 - mae: 0.1186 - val_loss: 0.0381 - val_mae: 0.1169
# Epoch 257/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0356 - mae: 0.1170 - val_loss: 0.0388 - val_mae: 0.1172
# Epoch 258/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0355 - mae: 0.1178 - val_loss: 0.0490 - val_mae: 0.1224
# Epoch 259/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0358 - mae: 0.1160 - val_loss: 0.0441 - val_mae: 0.1194
# Epoch 260/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0357 - mae: 0.1155 - val_loss: 0.0372 - val_mae: 0.1225
# Epoch 261/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0355 - mae: 0.1221 - val_loss: 0.0356 - val_mae: 0.1177
# Epoch 262/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0353 - mae: 0.1197 - val_loss: 0.0384 - val_mae: 0.1171
# Epoch 263/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0350 - mae: 0.1167 - val_loss: 0.0372 - val_mae: 0.1163
# Epoch 264/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0350 - mae: 0.1166 - val_loss: 0.0364 - val_mae: 0.1161
# Epoch 265/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0348 - mae: 0.1166 - val_loss: 0.0317 - val_mae: 0.1163
# Epoch 266/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0368 - mae: 0.1222 - val_loss: 0.0365 - val_mae: 0.1156
# Epoch 267/1000
# 451/451 [==============================] - 0s 54us/step - loss: 0.0346 - mae: 0.1149 - val_loss: 0.0467 - val_mae: 0.1204
# Epoch 268/1000
# 451/451 [==============================] - 0s 46us/step - loss: 0.0354 - mae: 0.1158 - val_loss: 0.0315 - val_mae: 0.1142
# Epoch 269/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0358 - mae: 0.1206 - val_loss: 0.0504 - val_mae: 0.1225
# Epoch 270/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0352 - mae: 0.1146 - val_loss: 0.0385 - val_mae: 0.1164
# Epoch 271/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0344 - mae: 0.1156 - val_loss: 0.0323 - val_mae: 0.1186
# Epoch 272/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0371 - mae: 0.1230 - val_loss: 0.0373 - val_mae: 0.1155
# Epoch 273/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0337 - mae: 0.1140 - val_loss: 0.0319 - val_mae: 0.1138
# Epoch 274/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0341 - mae: 0.1170 - val_loss: 0.0354 - val_mae: 0.1144
# Epoch 275/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0338 - mae: 0.1142 - val_loss: 0.0312 - val_mae: 0.1136
# Epoch 276/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0340 - mae: 0.1181 - val_loss: 0.0377 - val_mae: 0.1148
# Epoch 277/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0339 - mae: 0.1147 - val_loss: 0.0358 - val_mae: 0.1145
# Epoch 278/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0335 - mae: 0.1135 - val_loss: 0.0357 - val_mae: 0.1142
# Epoch 279/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0331 - mae: 0.1139 - val_loss: 0.0381 - val_mae: 0.1150
# Epoch 280/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0330 - mae: 0.1137 - val_loss: 0.0400 - val_mae: 0.1158
# Epoch 281/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0334 - mae: 0.1140 - val_loss: 0.0373 - val_mae: 0.1154
# Epoch 282/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0330 - mae: 0.1137 - val_loss: 0.0358 - val_mae: 0.1150
# Epoch 283/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0328 - mae: 0.1141 - val_loss: 0.0330 - val_mae: 0.1155
# Epoch 284/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0327 - mae: 0.1161 - val_loss: 0.0374 - val_mae: 0.1145
# Epoch 285/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0325 - mae: 0.1120 - val_loss: 0.0339 - val_mae: 0.1132
# Epoch 286/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0329 - mae: 0.1146 - val_loss: 0.0397 - val_mae: 0.1152
# Epoch 287/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0330 - mae: 0.1123 - val_loss: 0.0401 - val_mae: 0.1157
# Epoch 288/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0330 - mae: 0.1124 - val_loss: 0.0413 - val_mae: 0.1157
# Epoch 289/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0329 - mae: 0.1117 - val_loss: 0.0373 - val_mae: 0.1144
# Epoch 290/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0323 - mae: 0.1119 - val_loss: 0.0351 - val_mae: 0.1196
# Epoch 291/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0327 - mae: 0.1166 - val_loss: 0.0408 - val_mae: 0.1155
# Epoch 292/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0326 - mae: 0.1121 - val_loss: 0.0383 - val_mae: 0.1148
# Epoch 293/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0321 - mae: 0.1126 - val_loss: 0.0314 - val_mae: 0.1117
# Epoch 294/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0323 - mae: 0.1128 - val_loss: 0.0345 - val_mae: 0.1123
# Epoch 295/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0318 - mae: 0.1112 - val_loss: 0.0299 - val_mae: 0.1110
# Epoch 296/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0330 - mae: 0.1145 - val_loss: 0.0399 - val_mae: 0.1155
# Epoch 297/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0318 - mae: 0.1098 - val_loss: 0.0374 - val_mae: 0.1137
# Epoch 298/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0316 - mae: 0.1103 - val_loss: 0.0423 - val_mae: 0.1162
# Epoch 299/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0319 - mae: 0.1091 - val_loss: 0.0345 - val_mae: 0.1120
# Epoch 300/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0312 - mae: 0.1107 - val_loss: 0.0340 - val_mae: 0.1117
# Epoch 301/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0311 - mae: 0.1106 - val_loss: 0.0352 - val_mae: 0.1120
# Epoch 302/1000
# 451/451 [==============================] - 0s 49us/step - loss: 0.0308 - mae: 0.1093 - val_loss: 0.0303 - val_mae: 0.1110
# Epoch 303/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.0313 - mae: 0.1119 - val_loss: 0.0345 - val_mae: 0.1117
# Epoch 304/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0311 - mae: 0.1081 - val_loss: 0.0325 - val_mae: 0.1108
# Epoch 305/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0308 - mae: 0.1104 - val_loss: 0.0334 - val_mae: 0.1118
# Epoch 306/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0309 - mae: 0.1106 - val_loss: 0.0301 - val_mae: 0.1141
# Epoch 307/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0314 - mae: 0.1139 - val_loss: 0.0288 - val_mae: 0.1103
# Epoch 308/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0313 - mae: 0.1121 - val_loss: 0.0291 - val_mae: 0.1093
# Epoch 309/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0313 - mae: 0.1118 - val_loss: 0.0315 - val_mae: 0.1094
# Epoch 310/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0304 - mae: 0.1095 - val_loss: 0.0340 - val_mae: 0.1103
# Epoch 311/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0301 - mae: 0.1079 - val_loss: 0.0303 - val_mae: 0.1109
# Epoch 312/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0302 - mae: 0.1095 - val_loss: 0.0369 - val_mae: 0.1117
# Epoch 313/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0304 - mae: 0.1096 - val_loss: 0.0364 - val_mae: 0.1115
# Epoch 314/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0301 - mae: 0.1076 - val_loss: 0.0335 - val_mae: 0.1103
# Epoch 315/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0298 - mae: 0.1078 - val_loss: 0.0345 - val_mae: 0.1106
# Epoch 316/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0297 - mae: 0.1078 - val_loss: 0.0319 - val_mae: 0.1095
# Epoch 317/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0296 - mae: 0.1080 - val_loss: 0.0283 - val_mae: 0.1089
# Epoch 318/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0308 - mae: 0.1127 - val_loss: 0.0315 - val_mae: 0.1087
# Epoch 319/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0298 - mae: 0.1081 - val_loss: 0.0284 - val_mae: 0.1081
# Epoch 320/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0299 - mae: 0.1097 - val_loss: 0.0295 - val_mae: 0.1094
# Epoch 321/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0292 - mae: 0.1084 - val_loss: 0.0317 - val_mae: 0.1109
# Epoch 322/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0293 - mae: 0.1098 - val_loss: 0.0330 - val_mae: 0.1100
# Epoch 323/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0292 - mae: 0.1074 - val_loss: 0.0298 - val_mae: 0.1096
# Epoch 324/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0293 - mae: 0.1088 - val_loss: 0.0292 - val_mae: 0.1107
# Epoch 325/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0296 - mae: 0.1095 - val_loss: 0.0321 - val_mae: 0.1095
# Epoch 326/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0287 - mae: 0.1067 - val_loss: 0.0337 - val_mae: 0.1134
# Epoch 327/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0291 - mae: 0.1088 - val_loss: 0.0324 - val_mae: 0.1100
# Epoch 328/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0289 - mae: 0.1073 - val_loss: 0.0326 - val_mae: 0.1090
# Epoch 329/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0284 - mae: 0.1050 - val_loss: 0.0301 - val_mae: 0.1076
# Epoch 330/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0284 - mae: 0.1064 - val_loss: 0.0306 - val_mae: 0.1078
# Epoch 331/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0285 - mae: 0.1064 - val_loss: 0.0306 - val_mae: 0.1074
# Epoch 332/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0282 - mae: 0.1048 - val_loss: 0.0273 - val_mae: 0.1061
# Epoch 333/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0288 - mae: 0.1067 - val_loss: 0.0310 - val_mae: 0.1077
# Epoch 334/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0281 - mae: 0.1043 - val_loss: 0.0293 - val_mae: 0.1071
# Epoch 335/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0277 - mae: 0.1048 - val_loss: 0.0335 - val_mae: 0.1096
# Epoch 336/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0280 - mae: 0.1043 - val_loss: 0.0315 - val_mae: 0.1086
# Epoch 337/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0278 - mae: 0.1038 - val_loss: 0.0276 - val_mae: 0.1080
# Epoch 338/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0280 - mae: 0.1067 - val_loss: 0.0306 - val_mae: 0.1081
# Epoch 339/1000
# 451/451 [==============================] - 0s 43us/step - loss: 0.0275 - mae: 0.1046 - val_loss: 0.0307 - val_mae: 0.1074
# Epoch 340/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0279 - mae: 0.1043 - val_loss: 0.0307 - val_mae: 0.1073
# Epoch 341/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0275 - mae: 0.1033 - val_loss: 0.0270 - val_mae: 0.1061
# Epoch 342/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0276 - mae: 0.1061 - val_loss: 0.0375 - val_mae: 0.1121
# Epoch 343/1000
# 451/451 [==============================] - 0s 45us/step - loss: 0.0283 - mae: 0.1044 - val_loss: 0.0338 - val_mae: 0.1094
# Epoch 344/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0275 - mae: 0.1036 - val_loss: 0.0302 - val_mae: 0.1074
# Epoch 345/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0271 - mae: 0.1034 - val_loss: 0.0362 - val_mae: 0.1109
# Epoch 346/1000
# 451/451 [==============================] - 0s 41us/step - loss: 0.0277 - mae: 0.1030 - val_loss: 0.0318 - val_mae: 0.1076
# Epoch 347/1000
# 451/451 [==============================] - 0s 44us/step - loss: 0.0272 - mae: 0.1036 - val_loss: 0.0268 - val_mae: 0.1064
# Epoch 348/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0287 - mae: 0.1080 - val_loss: 0.0295 - val_mae: 0.1061
# Epoch 349/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0270 - mae: 0.1029 - val_loss: 0.0300 - val_mae: 0.1066
# Epoch 350/1000
# 451/451 [==============================] - 0s 42us/step - loss: 0.0268 - mae: 0.1029 - val_loss: 0.0300 - val_mae: 0.1068
# Epoch 351/1000
# ...
# Epoch 885/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0149 - mae: 0.0819 - val_loss: 0.0177 - val_mae: 0.0848
# Epoch 886/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0152 - mae: 0.0824 - val_loss: 0.0182 - val_mae: 0.0858
# Epoch 887/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0150 - mae: 0.0822 - val_loss: 0.0177 - val_mae: 0.0847
# Epoch 888/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0150 - mae: 0.0824 - val_loss: 0.0179 - val_mae: 0.0850
# Epoch 889/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0150 - mae: 0.0820 - val_loss: 0.0181 - val_mae: 0.0857
# Epoch 890/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0151 - mae: 0.0817 - val_loss: 0.0173 - val_mae: 0.0838
# Epoch 891/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0149 - mae: 0.0820 - val_loss: 0.0185 - val_mae: 0.0866
# Epoch 892/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0150 - mae: 0.0821 - val_loss: 0.0178 - val_mae: 0.0846
# Epoch 893/1000
# 451/451 [==============================] - 0s 39us/step - loss: 0.0151 - mae: 0.0824 - val_loss: 0.0175 - val_mae: 0.0838
# Epoch 894/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0150 - mae: 0.0823 - val_loss: 0.0176 - val_mae: 0.0839
# Epoch 895/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0150 - mae: 0.0824 - val_loss: 0.0181 - val_mae: 0.0850
# Epoch 896/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0152 - mae: 0.0827 - val_loss: 0.0181 - val_mae: 0.0849
# Epoch 897/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0824 - val_loss: 0.0173 - val_mae: 0.0835
# Epoch 898/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0150 - mae: 0.0825 - val_loss: 0.0173 - val_mae: 0.0836
# Epoch 899/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0151 - mae: 0.0830 - val_loss: 0.0172 - val_mae: 0.0858
# Epoch 900/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0152 - mae: 0.0841 - val_loss: 0.0171 - val_mae: 0.0836
# Epoch 901/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0152 - mae: 0.0830 - val_loss: 0.0173 - val_mae: 0.0839
# Epoch 902/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0825 - val_loss: 0.0176 - val_mae: 0.0845
# Epoch 903/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0150 - mae: 0.0826 - val_loss: 0.0173 - val_mae: 0.0836
# Epoch 904/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0150 - mae: 0.0823 - val_loss: 0.0172 - val_mae: 0.0833
# Epoch 905/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0824 - val_loss: 0.0180 - val_mae: 0.0853
# Epoch 906/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0150 - mae: 0.0819 - val_loss: 0.0185 - val_mae: 0.0868
# Epoch 907/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0821 - val_loss: 0.0173 - val_mae: 0.0836
# Epoch 908/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0148 - mae: 0.0823 - val_loss: 0.0174 - val_mae: 0.0839
# Epoch 909/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0149 - mae: 0.0819 - val_loss: 0.0218 - val_mae: 0.0871
# Epoch 910/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0164 - mae: 0.0855 - val_loss: 0.0190 - val_mae: 0.0882
# Epoch 911/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0152 - mae: 0.0817 - val_loss: 0.0172 - val_mae: 0.0833
# Epoch 912/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0151 - mae: 0.0826 - val_loss: 0.0173 - val_mae: 0.0832
# Epoch 913/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0825 - val_loss: 0.0170 - val_mae: 0.0830
# Epoch 914/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0150 - mae: 0.0825 - val_loss: 0.0178 - val_mae: 0.0851
# Epoch 915/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0151 - mae: 0.0821 - val_loss: 0.0176 - val_mae: 0.0842
# Epoch 916/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0816 - val_loss: 0.0178 - val_mae: 0.0851
# Epoch 917/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0149 - mae: 0.0818 - val_loss: 0.0180 - val_mae: 0.0854
# Epoch 918/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0815 - val_loss: 0.0174 - val_mae: 0.0838
# Epoch 919/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0817 - val_loss: 0.0172 - val_mae: 0.0835
# Epoch 920/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0151 - mae: 0.0814 - val_loss: 0.0171 - val_mae: 0.0832
# Epoch 921/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0148 - mae: 0.0815 - val_loss: 0.0171 - val_mae: 0.0829
# Epoch 922/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0150 - mae: 0.0821 - val_loss: 0.0171 - val_mae: 0.0830
# Epoch 923/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0148 - mae: 0.0816 - val_loss: 0.0175 - val_mae: 0.0836
# Epoch 924/1000
# 451/451 [==============================] - 0s 40us/step - loss: 0.0148 - mae: 0.0812 - val_loss: 0.0189 - val_mae: 0.0870
# Epoch 925/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0152 - mae: 0.0834 - val_loss: 0.0169 - val_mae: 0.0849
# Epoch 926/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0151 - mae: 0.0832 - val_loss: 0.0195 - val_mae: 0.0905
# Epoch 927/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0152 - mae: 0.0831 - val_loss: 0.0174 - val_mae: 0.0833
# Epoch 928/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0153 - mae: 0.0827 - val_loss: 0.0172 - val_mae: 0.0834
# Epoch 929/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0818 - val_loss: 0.0175 - val_mae: 0.0850
# Epoch 930/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0151 - mae: 0.0835 - val_loss: 0.0181 - val_mae: 0.0879
# Epoch 931/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0153 - mae: 0.0839 - val_loss: 0.0180 - val_mae: 0.0866
# Epoch 932/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0147 - mae: 0.0820 - val_loss: 0.0183 - val_mae: 0.0869
# Epoch 933/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0819 - val_loss: 0.0173 - val_mae: 0.0839
# Epoch 934/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0824 - val_loss: 0.0179 - val_mae: 0.0852
# Epoch 935/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0147 - mae: 0.0819 - val_loss: 0.0174 - val_mae: 0.0835
# Epoch 936/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0148 - mae: 0.0822 - val_loss: 0.0182 - val_mae: 0.0857
# Epoch 937/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0818 - val_loss: 0.0186 - val_mae: 0.0870
# Epoch 938/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0149 - mae: 0.0817 - val_loss: 0.0176 - val_mae: 0.0838
# Epoch 939/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0151 - mae: 0.0828 - val_loss: 0.0176 - val_mae: 0.0840
# Epoch 940/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0148 - mae: 0.0815 - val_loss: 0.0183 - val_mae: 0.0875
# Epoch 941/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0147 - mae: 0.0819 - val_loss: 0.0184 - val_mae: 0.0870
# Epoch 942/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0149 - mae: 0.0824 - val_loss: 0.0203 - val_mae: 0.0914
# Epoch 943/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0151 - mae: 0.0822 - val_loss: 0.0169 - val_mae: 0.0826
# Epoch 944/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0153 - mae: 0.0833 - val_loss: 0.0177 - val_mae: 0.0826
# Epoch 945/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0818 - val_loss: 0.0186 - val_mae: 0.0876
# Epoch 946/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0149 - mae: 0.0818 - val_loss: 0.0188 - val_mae: 0.0834
# Epoch 947/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0156 - mae: 0.0830 - val_loss: 0.0174 - val_mae: 0.0844
# Epoch 948/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0146 - mae: 0.0814 - val_loss: 0.0172 - val_mae: 0.0830
# Epoch 949/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0149 - mae: 0.0822 - val_loss: 0.0170 - val_mae: 0.0826
# Epoch 950/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0145 - mae: 0.0817 - val_loss: 0.0176 - val_mae: 0.0841
# Epoch 951/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0148 - mae: 0.0820 - val_loss: 0.0170 - val_mae: 0.0832
# Epoch 952/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0151 - mae: 0.0833 - val_loss: 0.0175 - val_mae: 0.0840
# Epoch 953/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0147 - mae: 0.0817 - val_loss: 0.0177 - val_mae: 0.0844
# Epoch 954/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0817 - val_loss: 0.0203 - val_mae: 0.0850
# Epoch 955/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0158 - mae: 0.0840 - val_loss: 0.0186 - val_mae: 0.0877
# Epoch 956/1000
# 451/451 [==============================] - 0s 38us/step - loss: 0.0145 - mae: 0.0803 - val_loss: 0.0180 - val_mae: 0.0854
# Epoch 957/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0147 - mae: 0.0813 - val_loss: 0.0170 - val_mae: 0.0829
# Epoch 958/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0147 - mae: 0.0814 - val_loss: 0.0175 - val_mae: 0.0839
# Epoch 959/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0147 - mae: 0.0815 - val_loss: 0.0177 - val_mae: 0.0843
# Epoch 960/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0147 - mae: 0.0816 - val_loss: 0.0176 - val_mae: 0.0845
# Epoch 961/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0150 - mae: 0.0818 - val_loss: 0.0171 - val_mae: 0.0830
# Epoch 962/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0146 - mae: 0.0810 - val_loss: 0.0168 - val_mae: 0.0824
# Epoch 963/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0146 - mae: 0.0813 - val_loss: 0.0168 - val_mae: 0.0821
# Epoch 964/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0147 - mae: 0.0817 - val_loss: 0.0178 - val_mae: 0.0851
# Epoch 965/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0146 - mae: 0.0818 - val_loss: 0.0170 - val_mae: 0.0829
# Epoch 966/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0149 - mae: 0.0816 - val_loss: 0.0167 - val_mae: 0.0824
# Epoch 967/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0814 - val_loss: 0.0169 - val_mae: 0.0829
# Epoch 968/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0148 - mae: 0.0813 - val_loss: 0.0169 - val_mae: 0.0827
# Epoch 969/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0149 - mae: 0.0823 - val_loss: 0.0169 - val_mae: 0.0826
# Epoch 970/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0145 - mae: 0.0812 - val_loss: 0.0172 - val_mae: 0.0830
# Epoch 971/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0146 - mae: 0.0815 - val_loss: 0.0175 - val_mae: 0.0841
# Epoch 972/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0145 - mae: 0.0813 - val_loss: 0.0169 - val_mae: 0.0821
# Epoch 973/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0146 - mae: 0.0818 - val_loss: 0.0182 - val_mae: 0.0861
# Epoch 974/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0146 - mae: 0.0813 - val_loss: 0.0188 - val_mae: 0.0883
# Epoch 975/1000
# 451/451 [==============================] - 0s 34us/step - loss: 0.0147 - mae: 0.0819 - val_loss: 0.0172 - val_mae: 0.0831
# Epoch 976/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0817 - val_loss: 0.0173 - val_mae: 0.0831
# Epoch 977/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0147 - mae: 0.0811 - val_loss: 0.0174 - val_mae: 0.0832
# Epoch 978/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0150 - mae: 0.0821 - val_loss: 0.0172 - val_mae: 0.0829
# Epoch 979/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0146 - mae: 0.0816 - val_loss: 0.0222 - val_mae: 0.0948
# Epoch 980/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0156 - mae: 0.0822 - val_loss: 0.0174 - val_mae: 0.0831
# Epoch 981/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0146 - mae: 0.0822 - val_loss: 0.0237 - val_mae: 0.0967
# Epoch 982/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0155 - mae: 0.0822 - val_loss: 0.0170 - val_mae: 0.0823
# Epoch 983/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0148 - mae: 0.0822 - val_loss: 0.0217 - val_mae: 0.0952
# Epoch 984/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0152 - mae: 0.0822 - val_loss: 0.0170 - val_mae: 0.0823
# Epoch 985/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0144 - mae: 0.0815 - val_loss: 0.0177 - val_mae: 0.0829
# Epoch 986/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0149 - mae: 0.0827 - val_loss: 0.0173 - val_mae: 0.0829
# Epoch 987/1000
# 451/451 [==============================] - 0s 37us/step - loss: 0.0148 - mae: 0.0809 - val_loss: 0.0169 - val_mae: 0.0823
# Epoch 988/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0146 - mae: 0.0814 - val_loss: 0.0178 - val_mae: 0.0833
# Epoch 989/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0151 - mae: 0.0824 - val_loss: 0.0174 - val_mae: 0.0839
# Epoch 990/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0145 - mae: 0.0811 - val_loss: 0.0173 - val_mae: 0.0830
# Epoch 991/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0144 - mae: 0.0806 - val_loss: 0.0200 - val_mae: 0.0904
# Epoch 992/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0147 - mae: 0.0807 - val_loss: 0.0177 - val_mae: 0.0835
# Epoch 993/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0147 - mae: 0.0817 - val_loss: 0.0172 - val_mae: 0.0826
# Epoch 994/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0145 - mae: 0.0803 - val_loss: 0.0174 - val_mae: 0.0832
# Epoch 995/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0146 - mae: 0.0807 - val_loss: 0.0176 - val_mae: 0.0837
# Epoch 996/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0145 - mae: 0.0809 - val_loss: 0.0182 - val_mae: 0.0858
# Epoch 997/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0145 - mae: 0.0807 - val_loss: 0.0172 - val_mae: 0.0827
# Epoch 998/1000
# 451/451 [==============================] - 0s 35us/step - loss: 0.0146 - mae: 0.0813 - val_loss: 0.0170 - val_mae: 0.0823
# Epoch 999/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0145 - mae: 0.0811 - val_loss: 0.0170 - val_mae: 0.0821
# Epoch 1000/1000
# 451/451 [==============================] - 0s 36us/step - loss: 0.0146 - mae: 0.0817 - val_loss: 0.0195 - val_mae: 0.0846

# %%
"""model_path = os.path.join(data_folder, "model")
# Import the exported model in future runs using the greyed out line below (remove the hastag)
model = pickle.load(open(os.path.join(model_path, "ReinNN.pkl"), "rb"))"""
# Out:
# 'model_path = os.path.join(data_folder, "model")\n# Import the exported model in future runs using the greyed out line below (remove the hastag)\nmodel = pickle.load(open(os.path.join(model_path, "ReinNN.pkl"), "rb"))'

# %%
for i in hml_list:

    ## Import the train and test dataframes. Drop the 'dateRep' column as it is not need for the prediciton.
    train_X = pd.read_csv(os.path.join(data_path, "train", 'train_x_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)
    train_y = pd.read_csv(os.path.join(data_path, "train", 'train_y_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)
    ## '.sample' randomises the dataframe as the validation test below will take the bottom 20% of the data
    ## 'frac=1' means it will use all the data and 'random_state=1' keeps the resample consistent between df's
    test_x = pd.read_csv(os.path.join(data_path, "test", 'test_x_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)
    test_y = pd.read_csv(os.path.join(data_path, "test", 'test_y_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)

    ## Initialise Scalars so that data is normalised to 1.
    sc_x = StandardScaler()
    sc_y = StandardScaler()
    ## Normalise the data using the scalar.
    X_train = sc_x.fit_transform(train_X)
    X_test = sc_x.transform(test_x)

    y_train = sc_y.fit_transform(train_y)
    y_test = sc_y.transform(test_y)

    # Calculate the predicted deaths according to the neural net model
    test_x["gold_pred"] = sc_y.inverse_transform(classifier.predict(X_test))
    # Calculate the predicted deaths according to the neural net model
    train_X["gold_pred"] = sc_y.inverse_transform(classifier.predict(X_train))
    #df1 = pd.concat([test_x, train_X], axis=1)
    df= train_X.merge(train_y,left_index=True, right_index=True)
    # We merge the test dataframes together
    df1 = test_x.merge(test_y, left_index=True, right_index=True)
    # We append the test data to the train data
    df = df.append(df1)
    
    # Again read in the 'covid19_df' as df_global
    df_global = pd.read_csv(os.path.join(os.getcwd(), "Data_Export", "gold_df_" + i + ".csv"), index_col=0)
    # Merge in the 'deaths_pred' prediction column to compare to the real data
    df_global = df_global.merge(df["gold_pred"], left_index=True, right_index=True, how='left')
    df_global.index = pd.to_datetime(df_global.index)
    
    df_global.to_csv(os.path.join(os.getcwd(), "data_export", "gold_df_" + i + ".csv"))

# %%
# Import the three complete datasets.
lmh_list = [df_global_high, df_global_mid, df_global_low]
df_global_high = pd.read_csv(os.path.join(os.getcwd(), "Data_Export", "gold_df_high.csv"), index_col=0)
df_global_high.index = pd.to_datetime(df_global_high.index)
df_global_mid = pd.read_csv(os.path.join(os.getcwd(), "Data_Export", "gold_df_mid.csv"), index_col=0)
df_global_mid.index = pd.to_datetime(df_global_mid.index)
df_global_low = pd.read_csv(os.path.join(os.getcwd(), "Data_Export", "gold_df_low.csv"), index_col=0)
df_global_low.index = pd.to_datetime(df_global_low.index)

# %%
# Compute the prediction error
df_global_high['gold_pred_error'] = df_global_high['GOLDAMGBDollarD228NLBM'] - df_global_high['gold_pred']
# Compute the cumulative error for gold
df_global_high['cumulative_error'] = df_global_high['gold_pred_error'].cumsum()

df_global_mid['gold_pred_error'] = df_global_mid['GOLDAMGBDollarD228NLBM'] - df_global_mid['gold_pred']
df_global_mid['cumulative_error'] = df_global_mid['gold_pred_error'].cumsum()
df_global_low['gold_pred_error'] = df_global_low['GOLDAMGBDollarD228NLBM'] - df_global_low['gold_pred']
df_global_low['cumulative_error'] = df_global_low['gold_pred_error'].cumsum()

# %%
#for m, n in zip(hml_list, lmh_list): 
# Visualising the Linear Regression results.
fig, ax1 = plt.subplots()
j = 'GOLDAMGBDollarD228NLBM'
k = 'gold_pred_error'
l = 'gold_pred'

#ax1.plot(df_global.index, df_global[k], label=k, c='mediumturquoise')
ax1.axvline(x=dt.date(2020, 8, 1), linestyle='--', color='red', label='Real_Data_Cutoff')
ax1.axvline(x=dt.date(2016, 1, 1), linestyle='--', color='royalblue', label='Test_Data_Cutoff')

ax2 = ax1.twinx()
ax2.plot(df_global_high.index, df_global_high[j], label='gold (US $)', c='goldenrod')
ax2.plot(df_global_high.index, df_global_high[l], label='gold predicted (US $) ' + m, c='crimson')

#ax1.ylim(0, 15)
plt.title(j)
plt.xlabel('Date')
plt.grid()
ax1.legend(loc=2)
ax2.legend(loc=1)
fig.set_size_inches(18.5, 10.5)

ax1.set_xlabel('Date')
ax1.set_ylabel('Price (US $)')
ax2.set_ylabel('Price (US $)')
#plt.savefig('cumulative_error_20_countries_XGB_dpi300.jpeg', dpi=300)
# Out:
# Text(0, 0.5, 'Price (US $)')

# %%
## Calculate the mean absolute error and R2 scores for the predicted vs real test data.
print(f"Test data MAE score: {np.round(mean_absolute_error(df1.loc[df1.index < '2020-08-31'][gold_col], df1.loc[df1.index < '2020-08-31']['gold_pred']))}")
print(f"Test data R2 score: {np.round(r2_score(df1.loc[df1.index < '2020-08-31'][gold_col], df1.loc[df1.index < '2020-08-31']['gold_pred']))}")
## Calculate the mean absolute error and R2 scores for the predicted vs real all data.
print(f"All Data MAE score: {np.round(mean_absolute_error(df_global.loc[df_global.index < '2020-08-31'][gold_col], df_global.loc[df_global.index < '2020-08-31']['gold_pred']))}")
print(f"All Data R2 score: {np.round(r2_score(df_global.loc[df_global.index < '2020-08-31'][gold_col], df_global.loc[df_global.index < '2020-08-31']['gold_pred']))}")
# Out:
# Test data MAE score: 501.0
# Test data R2 score: -10.0
# All Data MAE score: 81.0
# All Data R2 score: 1.0

# %%
# Visualising the Linear Regression results.
fig, ax1 = plt.subplots()
j = 'GOLDAMGBDollarD228NLBM'
k = 'gold_pred_error'
l = 'gold_pred'

ax1.plot(df_global.index, df_global[k], label=k, c='mediumturquoise', linestyle=':')
ax1.axvline(x=dt.date(2020, 8, 1), linestyle='--', color='red', label='Real_Data_Cutoff')


ax2 = ax1.twinx()
ax2.plot(df_global.index, df_global[j], label='gold (US $)', c='goldenrod')
ax2.plot(df_global.index, df_global[l], label='gold predicted (US $)', c='crimson')

#ax1.ylim(0, 15)
plt.title(j)
plt.xlabel('Date')
plt.grid()
ax1.legend(loc=2)
ax2.legend(loc=1)
fig.set_size_inches(18.5, 10.5)

ax1.set_xlabel('Date')
ax1.set_ylabel('Error')
ax2.set_ylabel('Price (US $)')
#plt.savefig('cumulative_error_20_countries_XGB_dpi300.jpeg', dpi=300)
# Out:
# Text(0, 0.5, 'Price (US $)')

# %%
## Check for the directory and output the df_global dataframe.
if os.path.exists(os.path.join(os.getcwd(), "model_predictions")) is False:
    os.mkdir(os.path.join(os.getcwd(), "model_predictions"))
df_global.to_csv(os.path.join(os.getcwd(), "model_predictions", "Rein_nn_predictions.csv"))

# %%
plt.style.use("ggplot")

# %%
## Plot deaths vs predicted.
plt.figure(figsize=(8, 8))
plt.scatter(df1.GOLDAMGBDollarD228NLBM, df1.gold_pred)
plt.plot(df1.GOLDAMGBDollarD228NLBM, df1.GOLDAMGBDollarD228NLBM, color="black", linestyle="--")
plt.xlabel("GOLDAMGBDollarD228NLBM")
plt.ylabel("predicted gold")
plt.show()

# %%
## Plot deaths vs predicted.
plt.figure(figsize=(8, 8))
plt.scatter(df_global.GOLDAMGBDollarD228NLBM, df_global.gold_pred)
plt.plot(df_global.GOLDAMGBDollarD228NLBM, df_global.GOLDAMGBDollarD228NLBM, color="black", linestyle="--")
plt.xlabel("GOLDAMGBDollarD228NLBM")
plt.ylabel("predicted gold")
plt.show()

# %%
plt.rcdefaults()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import os
import datetime as dt
import matplotlib.dates as mdates
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, r2_score

# %%
from keras.models import Sequential
from keras.layers import Dropout, Dense
from sklearn.utils import shuffle
import sys

# %%
# Changes the font parameters for the charts
params = {'legend.fontsize': 14,
         'axes.labelsize': 16,
         'axes.titlesize': 16,
         'xtick.labelsize': 10,
         'ytick.labelsize': 10}
plt.rcParams.update(params)

# %%
params = {}

# %%
## Change to the 'Datasets directory'
gold_col = 'GOLDAMGBDollarD228NLBM' # 'GOLD_shift' 
initial_dir = os.getcwd()
data_path = os.path.join(os.getcwd(), "data")

# %%
parameter_list = ['Federal Debt Held by Federal Reserve Banks', 'Unemployment_Rate', 'IndustrialProductionGoldSilver21222S', 'All Employees, Retail Trade', 'FEDFUNDS', 'Fed Debt_Total Public Debt as Perc of GDP']
none_list = ['Industrial Production_Manufacturing (NAICS)']
parameter_list
# Out:
# ['Federal Debt Held by Federal Reserve Banks',
#  'Unemployment_Rate',
#  'IndustrialProductionGoldSilver21222S',
#  'All Employees, Retail Trade',
#  'FEDFUNDS',
#  'Fed Debt_Total Public Debt as Perc of GDP']

# %%
hml_list = ['high', 'mid', 'low']

# %%
for i in hml_list:
# Filter the dataframe and keep only the columns listed.

    ## Import the train and test dataframes. Drop the 'dateRep' column as it is not need for the prediciton.
    train_X = pd.read_csv(os.path.join(data_path, "train", 'train_x_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1).filter(parameter_list, axis=1)
    train_y = pd.read_csv(os.path.join(data_path, "train", 'train_y_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)
    ## '.sample' randomises the dataframe as the validation test below will take the bottom 20% of the data
    ## 'frac=1' means it will use all the data and 'random_state=1' keeps the resample consistent between df's
    test_x = pd.read_csv(os.path.join(data_path, "test", 'test_x_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1).filter(parameter_list, axis=1)
    test_y = pd.read_csv(os.path.join(data_path, "test", 'test_y_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)

    ## Initialise Scalars so that data is normalised to 1.
    sc_x = StandardScaler()
    sc_y = StandardScaler()
    ## Normalise the data using the scalar.
    X_train = sc_x.fit_transform(train_X)
    X_test = sc_x.transform(test_x)

    y_train = sc_y.fit_transform(train_y)
    y_test = sc_y.transform(test_y)
    
    
    ## Calculate the number of input 'test' columns.
    input_neuron = len(test_x.columns)
    
    ## Setup the model for training, parameters here can and should be adjusted to create the best model.
    classifier = Sequential()
    classifier.add(Dense(output_dim = 18, init = 'uniform', activation = 'relu', input_dim = input_neuron))
    classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu'))
    classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'linear'))

    classifier.compile(optimizer = 'SGD', loss = 'mean_squared_error', metrics = ["mae"])
    ## '.fit' starts the training. 30 seconds to 2 minutes to run.
    classifier.fit(X_train, y_train, batch_size = 16, nb_epoch = 500, validation_split= 0.8)


    model_path = os.path.join(os.getcwd(), "model")
    # Check if the relevant folders exist and create them if not
    if os.path.exists(model_path) is False:
        os.mkdir(model_path)
    # Export the model for future use to that you don't need to spend time training the model again
    pickle.dump(classifier, open(os.path.join(model_path, "ReinNN_" + i + ".pkl"), "wb"))
    train_X.head(3)
# Out:
# Train on 113 samples, validate on 457 samples
# Epoch 1/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9319 - mae: 0.7181 - val_loss: 1.0175 - val_mae: 0.7309
# Epoch 2/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.9309 - mae: 0.7097 - val_loss: 1.0190 - val_mae: 0.7216
# Epoch 3/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.9300 - mae: 0.6981 - val_loss: 1.0197 - val_mae: 0.7184
# Epoch 4/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.9291 - mae: 0.6946 - val_loss: 1.0219 - val_mae: 0.7103
# Epoch 5/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.9295 - mae: 0.6887 - val_loss: 1.0226 - val_mae: 0.7083
# Epoch 6/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.9291 - mae: 0.6818 - val_loss: 1.0250 - val_mae: 0.7020
# Epoch 7/500
# 113/113 [==============================] - 0s 279us/step - loss: 0.9291 - mae: 0.6754 - val_loss: 1.0236 - val_mae: 0.7052
# Epoch 8/500
# 113/113 [==============================] - 0s 293us/step - loss: 0.9289 - mae: 0.6794 - val_loss: 1.0243 - val_mae: 0.7035
# Epoch 9/500
# 113/113 [==============================] - 0s 298us/step - loss: 0.9288 - mae: 0.6797 - val_loss: 1.0244 - val_mae: 0.7030
# Epoch 10/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.9301 - mae: 0.6756 - val_loss: 1.0266 - val_mae: 0.6979
# Epoch 11/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.9310 - mae: 0.6730 - val_loss: 1.0276 - val_mae: 0.6958
# Epoch 12/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.9305 - mae: 0.6730 - val_loss: 1.0275 - val_mae: 0.6959
# Epoch 13/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.9296 - mae: 0.6706 - val_loss: 1.0265 - val_mae: 0.6978
# Epoch 14/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.9302 - mae: 0.6735 - val_loss: 1.0295 - val_mae: 0.6920
# Epoch 15/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.9302 - mae: 0.6632 - val_loss: 1.0285 - val_mae: 0.6938
# Epoch 16/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.9304 - mae: 0.6648 - val_loss: 1.0286 - val_mae: 0.6934
# Epoch 17/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.9301 - mae: 0.6666 - val_loss: 1.0305 - val_mae: 0.6900
# Epoch 18/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.9317 - mae: 0.6651 - val_loss: 1.0189 - val_mae: 0.7188
# Epoch 19/500
# 113/113 [==============================] - 0s 255us/step - loss: 0.9304 - mae: 0.6988 - val_loss: 1.0196 - val_mae: 0.7157
# Epoch 20/500
# 113/113 [==============================] - 0s 294us/step - loss: 0.9296 - mae: 0.6964 - val_loss: 1.0226 - val_mae: 0.7059
# Epoch 21/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.9283 - mae: 0.6795 - val_loss: 1.0175 - val_mae: 0.7241
# Epoch 22/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.9294 - mae: 0.7009 - val_loss: 1.0183 - val_mae: 0.7199
# Epoch 23/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.9286 - mae: 0.6990 - val_loss: 1.0212 - val_mae: 0.7092
# Epoch 24/500
# 113/113 [==============================] - 0s 295us/step - loss: 0.9290 - mae: 0.6813 - val_loss: 1.0171 - val_mae: 0.7255
# Epoch 25/500
# 113/113 [==============================] - 0s 307us/step - loss: 0.9295 - mae: 0.7018 - val_loss: 1.0164 - val_mae: 0.7297
# Epoch 26/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.9309 - mae: 0.7038 - val_loss: 1.0169 - val_mae: 0.7254
# Epoch 27/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.9292 - mae: 0.7010 - val_loss: 1.0187 - val_mae: 0.7167
# Epoch 28/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.9284 - mae: 0.6916 - val_loss: 1.0208 - val_mae: 0.7094
# Epoch 29/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.9289 - mae: 0.6882 - val_loss: 1.0213 - val_mae: 0.7075
# Epoch 30/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.9275 - mae: 0.6840 - val_loss: 1.0218 - val_mae: 0.7061
# Epoch 31/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.9279 - mae: 0.6791 - val_loss: 1.0234 - val_mae: 0.7018
# Epoch 32/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.9287 - mae: 0.6761 - val_loss: 1.0240 - val_mae: 0.7001
# Epoch 33/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.9284 - mae: 0.6744 - val_loss: 1.0236 - val_mae: 0.7010
# Epoch 34/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.9281 - mae: 0.6729 - val_loss: 1.0221 - val_mae: 0.7044
# Epoch 35/500
# 113/113 [==============================] - 0s 265us/step - loss: 0.9280 - mae: 0.6807 - val_loss: 1.0223 - val_mae: 0.7037
# Epoch 36/500
# 113/113 [==============================] - 0s 267us/step - loss: 0.9278 - mae: 0.6770 - val_loss: 1.0210 - val_mae: 0.7067
# Epoch 37/500
# 113/113 [==============================] - 0s 305us/step - loss: 0.9269 - mae: 0.6832 - val_loss: 1.0212 - val_mae: 0.7059
# Epoch 38/500
# 113/113 [==============================] - 0s 299us/step - loss: 0.9271 - mae: 0.6811 - val_loss: 1.0208 - val_mae: 0.7066
# Epoch 39/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.9276 - mae: 0.6805 - val_loss: 1.0190 - val_mae: 0.7118
# Epoch 40/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.9270 - mae: 0.6882 - val_loss: 1.0178 - val_mae: 0.7157
# Epoch 41/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.9270 - mae: 0.6927 - val_loss: 1.0206 - val_mae: 0.7060
# Epoch 42/500
# 113/113 [==============================] - 0s 278us/step - loss: 0.9268 - mae: 0.6819 - val_loss: 1.0210 - val_mae: 0.7047
# Epoch 43/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.9275 - mae: 0.6828 - val_loss: 1.0212 - val_mae: 0.7038
# Epoch 44/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.9287 - mae: 0.6846 - val_loss: 1.0166 - val_mae: 0.7180
# Epoch 45/500
# 113/113 [==============================] - 0s 291us/step - loss: 0.9266 - mae: 0.6956 - val_loss: 1.0174 - val_mae: 0.7142
# Epoch 46/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.9265 - mae: 0.6916 - val_loss: 1.0182 - val_mae: 0.7108
# Epoch 47/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.9261 - mae: 0.6884 - val_loss: 1.0191 - val_mae: 0.7075
# Epoch 48/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.9261 - mae: 0.6846 - val_loss: 1.0198 - val_mae: 0.7050
# Epoch 49/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.9270 - mae: 0.6779 - val_loss: 1.0192 - val_mae: 0.7061
# Epoch 50/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.9260 - mae: 0.6846 - val_loss: 1.0198 - val_mae: 0.7038
# Epoch 51/500
# 113/113 [==============================] - 0s 300us/step - loss: 0.9257 - mae: 0.6788 - val_loss: 1.0204 - val_mae: 0.7016
# Epoch 52/500
# 113/113 [==============================] - 0s 330us/step - loss: 0.9261 - mae: 0.6773 - val_loss: 1.0235 - val_mae: 0.6942
# Epoch 53/500
# 113/113 [==============================] - 0s 291us/step - loss: 0.9262 - mae: 0.6687 - val_loss: 1.0237 - val_mae: 0.6933
# Epoch 54/500
# 113/113 [==============================] - 0s 278us/step - loss: 0.9260 - mae: 0.6706 - val_loss: 1.0269 - val_mae: 0.6871
# Epoch 55/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.9272 - mae: 0.6605 - val_loss: 1.0263 - val_mae: 0.6875
# Epoch 56/500
# 113/113 [==============================] - 0s 261us/step - loss: 0.9269 - mae: 0.6643 - val_loss: 1.0271 - val_mae: 0.6857
# Epoch 57/500
# 113/113 [==============================] - 0s 255us/step - loss: 0.9271 - mae: 0.6624 - val_loss: 1.0284 - val_mae: 0.6830
# Epoch 58/500
# 113/113 [==============================] - 0s 267us/step - loss: 0.9271 - mae: 0.6541 - val_loss: 1.0270 - val_mae: 0.6845
# Epoch 59/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.9274 - mae: 0.6584 - val_loss: 1.0259 - val_mae: 0.6855
# Epoch 60/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.9269 - mae: 0.6616 - val_loss: 1.0287 - val_mae: 0.6806
# Epoch 61/500
# 113/113 [==============================] - 0s 273us/step - loss: 0.9272 - mae: 0.6513 - val_loss: 1.0284 - val_mae: 0.6803
# Epoch 62/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.9273 - mae: 0.6505 - val_loss: 1.0264 - val_mae: 0.6823
# Epoch 63/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.9255 - mae: 0.6539 - val_loss: 1.0150 - val_mae: 0.7022
# Epoch 64/500
# 113/113 [==============================] - 0s 265us/step - loss: 0.9221 - mae: 0.6790 - val_loss: 1.0142 - val_mae: 0.7025
# Epoch 65/500
# 113/113 [==============================] - 0s 261us/step - loss: 0.9213 - mae: 0.6810 - val_loss: 1.0170 - val_mae: 0.6942
# Epoch 66/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.9210 - mae: 0.6680 - val_loss: 1.0090 - val_mae: 0.7127
# Epoch 67/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.9193 - mae: 0.6896 - val_loss: 1.0104 - val_mae: 0.7048
# Epoch 68/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.9178 - mae: 0.6805 - val_loss: 1.0100 - val_mae: 0.7033
# Epoch 69/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.9177 - mae: 0.6790 - val_loss: 1.0098 - val_mae: 0.7011
# Epoch 70/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.9165 - mae: 0.6770 - val_loss: 1.0030 - val_mae: 0.7212
# Epoch 71/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.9165 - mae: 0.7004 - val_loss: 1.0036 - val_mae: 0.7112
# Epoch 72/500
# 113/113 [==============================] - 0s 311us/step - loss: 0.9142 - mae: 0.6894 - val_loss: 1.0034 - val_mae: 0.7070
# Epoch 73/500
# 113/113 [==============================] - 0s 296us/step - loss: 0.9129 - mae: 0.6847 - val_loss: 1.0011 - val_mae: 0.7104
# Epoch 74/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.9119 - mae: 0.6861 - val_loss: 1.0000 - val_mae: 0.7088
# Epoch 75/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.9102 - mae: 0.6866 - val_loss: 0.9976 - val_mae: 0.7118
# Epoch 76/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.9092 - mae: 0.6870 - val_loss: 0.9922 - val_mae: 0.7370
# Epoch 77/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.9116 - mae: 0.7135 - val_loss: 0.9901 - val_mae: 0.7408
# Epoch 78/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.9104 - mae: 0.7189 - val_loss: 0.9874 - val_mae: 0.7260
# Epoch 79/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.9039 - mae: 0.7037 - val_loss: 0.9851 - val_mae: 0.7225
# Epoch 80/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.9014 - mae: 0.7003 - val_loss: 0.9831 - val_mae: 0.7131
# Epoch 81/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.8976 - mae: 0.6925 - val_loss: 0.9806 - val_mae: 0.7090
# Epoch 82/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.8957 - mae: 0.6821 - val_loss: 0.9727 - val_mae: 0.7243
# Epoch 83/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.8918 - mae: 0.7014 - val_loss: 0.9688 - val_mae: 0.7173
# Epoch 84/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.8870 - mae: 0.6955 - val_loss: 0.9651 - val_mae: 0.7086
# Epoch 85/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.8807 - mae: 0.6868 - val_loss: 0.9614 - val_mae: 0.6993
# Epoch 86/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.8756 - mae: 0.6794 - val_loss: 0.9565 - val_mae: 0.6935
# Epoch 87/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.8702 - mae: 0.6700 - val_loss: 0.9515 - val_mae: 0.6844
# Epoch 88/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.8648 - mae: 0.6622 - val_loss: 0.9448 - val_mae: 0.6805
# Epoch 89/500
# 113/113 [==============================] - 0s 302us/step - loss: 0.8582 - mae: 0.6520 - val_loss: 0.9380 - val_mae: 0.6750
# Epoch 90/500
# 113/113 [==============================] - 0s 273us/step - loss: 0.8509 - mae: 0.6491 - val_loss: 0.9311 - val_mae: 0.6642
# Epoch 91/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.8433 - mae: 0.6374 - val_loss: 0.9198 - val_mae: 0.6625
# Epoch 92/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.8307 - mae: 0.6380 - val_loss: 0.9050 - val_mae: 0.6645
# Epoch 93/500
# 113/113 [==============================] - 0s 290us/step - loss: 0.8201 - mae: 0.6413 - val_loss: 0.8779 - val_mae: 0.6765
# Epoch 94/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.7993 - mae: 0.6547 - val_loss: 0.8625 - val_mae: 0.6648
# Epoch 95/500
# 113/113 [==============================] - 0s 278us/step - loss: 0.7832 - mae: 0.6403 - val_loss: 0.8435 - val_mae: 0.6506
# Epoch 96/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.7631 - mae: 0.6289 - val_loss: 0.8218 - val_mae: 0.6415
# Epoch 97/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.7437 - mae: 0.6198 - val_loss: 0.7751 - val_mae: 0.6449
# Epoch 98/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.7051 - mae: 0.6221 - val_loss: 0.7032 - val_mae: 0.6484
# Epoch 99/500
# 113/113 [==============================] - 0s 333us/step - loss: 0.6467 - mae: 0.6312 - val_loss: 0.6125 - val_mae: 0.6366
# Epoch 100/500
# 113/113 [==============================] - 0s 298us/step - loss: 0.5719 - mae: 0.6224 - val_loss: 0.5492 - val_mae: 0.5848
# Epoch 101/500
# 113/113 [==============================] - 0s 291us/step - loss: 0.5111 - mae: 0.5727 - val_loss: 0.4950 - val_mae: 0.5485
# Epoch 102/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.4585 - mae: 0.5353 - val_loss: 0.4392 - val_mae: 0.5143
# Epoch 103/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.4067 - mae: 0.4998 - val_loss: 0.3866 - val_mae: 0.4835
# Epoch 104/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.3594 - mae: 0.4695 - val_loss: 0.3089 - val_mae: 0.4476
# Epoch 105/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.2970 - mae: 0.4378 - val_loss: 0.2696 - val_mae: 0.4145
# Epoch 106/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.2591 - mae: 0.4059 - val_loss: 0.2275 - val_mae: 0.3874
# Epoch 107/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.2240 - mae: 0.3811 - val_loss: 0.2080 - val_mae: 0.3712
# Epoch 108/500
# 113/113 [==============================] - 0s 258us/step - loss: 0.2050 - mae: 0.3654 - val_loss: 0.1954 - val_mae: 0.3595
# Epoch 109/500
# 113/113 [==============================] - 0s 256us/step - loss: 0.1912 - mae: 0.3544 - val_loss: 0.1849 - val_mae: 0.3491
# Epoch 110/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.1796 - mae: 0.3435 - val_loss: 0.1785 - val_mae: 0.3443
# Epoch 111/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.1726 - mae: 0.3375 - val_loss: 0.1715 - val_mae: 0.3351
# Epoch 112/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.1641 - mae: 0.3276 - val_loss: 0.1681 - val_mae: 0.3335
# Epoch 113/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.1602 - mae: 0.3244 - val_loss: 0.1666 - val_mae: 0.3237
# Epoch 114/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.1562 - mae: 0.3171 - val_loss: 0.1654 - val_mae: 0.3202
# Epoch 115/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.1532 - mae: 0.3113 - val_loss: 0.1620 - val_mae: 0.3209
# Epoch 116/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.1499 - mae: 0.3094 - val_loss: 0.1659 - val_mae: 0.3150
# Epoch 117/500
# 113/113 [==============================] - 0s 290us/step - loss: 0.1511 - mae: 0.3054 - val_loss: 0.1596 - val_mae: 0.3194
# Epoch 118/500
# 113/113 [==============================] - 0s 296us/step - loss: 0.1464 - mae: 0.3047 - val_loss: 0.1581 - val_mae: 0.3197
# Epoch 119/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.1445 - mae: 0.3045 - val_loss: 0.1565 - val_mae: 0.3202
# Epoch 120/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.1443 - mae: 0.3051 - val_loss: 0.1561 - val_mae: 0.3160
# Epoch 121/500
# 113/113 [==============================] - 0s 296us/step - loss: 0.1409 - mae: 0.2983 - val_loss: 0.1535 - val_mae: 0.3152
# Epoch 122/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.1386 - mae: 0.2969 - val_loss: 0.1541 - val_mae: 0.3082
# Epoch 123/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.1381 - mae: 0.2900 - val_loss: 0.1520 - val_mae: 0.3079
# Epoch 124/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.1358 - mae: 0.2887 - val_loss: 0.1506 - val_mae: 0.3066
# Epoch 125/500
# 113/113 [==============================] - 0s 258us/step - loss: 0.1350 - mae: 0.2870 - val_loss: 0.1489 - val_mae: 0.3082
# Epoch 126/500
# 113/113 [==============================] - 0s 251us/step - loss: 0.1335 - mae: 0.2868 - val_loss: 0.1484 - val_mae: 0.3065
# Epoch 127/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.1317 - mae: 0.2852 - val_loss: 0.1481 - val_mae: 0.3051
# Epoch 128/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.1315 - mae: 0.2829 - val_loss: 0.1480 - val_mae: 0.3040
# Epoch 129/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.1300 - mae: 0.2819 - val_loss: 0.1481 - val_mae: 0.2987
# Epoch 130/500
# 113/113 [==============================] - 0s 273us/step - loss: 0.1293 - mae: 0.2766 - val_loss: 0.1447 - val_mae: 0.3001
# Epoch 131/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.1275 - mae: 0.2772 - val_loss: 0.1789 - val_mae: 0.3353
# Epoch 132/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.1397 - mae: 0.3038 - val_loss: 0.1510 - val_mae: 0.3049
# Epoch 133/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.1270 - mae: 0.2812 - val_loss: 0.1474 - val_mae: 0.2985
# Epoch 134/500
# 113/113 [==============================] - 0s 254us/step - loss: 0.1248 - mae: 0.2724 - val_loss: 0.1446 - val_mae: 0.2967
# Epoch 135/500
# 113/113 [==============================] - 0s 256us/step - loss: 0.1237 - mae: 0.2710 - val_loss: 0.1439 - val_mae: 0.3044
# Epoch 136/500
# 113/113 [==============================] - 0s 252us/step - loss: 0.1269 - mae: 0.2782 - val_loss: 0.1398 - val_mae: 0.2964
# Epoch 137/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.1209 - mae: 0.2717 - val_loss: 0.1378 - val_mae: 0.2923
# Epoch 138/500
# 113/113 [==============================] - 0s 279us/step - loss: 0.1201 - mae: 0.2671 - val_loss: 0.1371 - val_mae: 0.2884
# Epoch 139/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.1188 - mae: 0.2640 - val_loss: 0.1366 - val_mae: 0.2834
# Epoch 140/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.1181 - mae: 0.2576 - val_loss: 0.1369 - val_mae: 0.2825
# Epoch 141/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.1172 - mae: 0.2566 - val_loss: 0.1356 - val_mae: 0.2818
# Epoch 142/500
# 113/113 [==============================] - 0s 267us/step - loss: 0.1156 - mae: 0.2550 - val_loss: 0.1341 - val_mae: 0.2818
# Epoch 143/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.1147 - mae: 0.2544 - val_loss: 0.1332 - val_mae: 0.2802
# Epoch 144/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.1143 - mae: 0.2531 - val_loss: 0.1333 - val_mae: 0.2865
# Epoch 145/500
# 113/113 [==============================] - 0s 278us/step - loss: 0.1134 - mae: 0.2582 - val_loss: 0.1312 - val_mae: 0.2801
# Epoch 146/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.1117 - mae: 0.2525 - val_loss: 0.1311 - val_mae: 0.2770
# Epoch 147/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.1118 - mae: 0.2484 - val_loss: 0.1303 - val_mae: 0.2753
# Epoch 148/500
# 113/113 [==============================] - 0s 255us/step - loss: 0.1094 - mae: 0.2458 - val_loss: 0.1294 - val_mae: 0.2741
# Epoch 149/500
# 113/113 [==============================] - 0s 249us/step - loss: 0.1086 - mae: 0.2441 - val_loss: 0.1597 - val_mae: 0.3045
# Epoch 150/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.1200 - mae: 0.2661 - val_loss: 0.1391 - val_mae: 0.2844
# Epoch 151/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.1104 - mae: 0.2542 - val_loss: 0.1324 - val_mae: 0.2743
# Epoch 152/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.1076 - mae: 0.2450 - val_loss: 0.1315 - val_mae: 0.2594
# Epoch 153/500
# 113/113 [==============================] - 0s 303us/step - loss: 0.1124 - mae: 0.2351 - val_loss: 0.1268 - val_mae: 0.2589
# Epoch 154/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.1080 - mae: 0.2309 - val_loss: 0.1243 - val_mae: 0.2597
# Epoch 155/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.1050 - mae: 0.2306 - val_loss: 0.1222 - val_mae: 0.2599
# Epoch 156/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.1035 - mae: 0.2314 - val_loss: 0.1230 - val_mae: 0.2563
# Epoch 157/500
# 113/113 [==============================] - 0s 265us/step - loss: 0.1037 - mae: 0.2259 - val_loss: 0.1193 - val_mae: 0.2681
# Epoch 158/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.1041 - mae: 0.2424 - val_loss: 0.1169 - val_mae: 0.2571
# Epoch 159/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.1027 - mae: 0.2318 - val_loss: 0.1159 - val_mae: 0.2585
# Epoch 160/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.1009 - mae: 0.2315 - val_loss: 0.1155 - val_mae: 0.2552
# Epoch 161/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0990 - mae: 0.2279 - val_loss: 0.1151 - val_mae: 0.2545
# Epoch 162/500
# 113/113 [==============================] - 0s 279us/step - loss: 0.0981 - mae: 0.2268 - val_loss: 0.1146 - val_mae: 0.2533
# Epoch 163/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0971 - mae: 0.2278 - val_loss: 0.1145 - val_mae: 0.2480
# Epoch 164/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.0970 - mae: 0.2209 - val_loss: 0.1138 - val_mae: 0.2477
# Epoch 165/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.0957 - mae: 0.2184 - val_loss: 0.1136 - val_mae: 0.2455
# Epoch 166/500
# 113/113 [==============================] - 0s 248us/step - loss: 0.0959 - mae: 0.2183 - val_loss: 0.1175 - val_mae: 0.2388
# Epoch 167/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.1000 - mae: 0.2164 - val_loss: 0.1130 - val_mae: 0.2397
# Epoch 168/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0964 - mae: 0.2140 - val_loss: 0.1099 - val_mae: 0.2434
# Epoch 169/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.0934 - mae: 0.2162 - val_loss: 0.1100 - val_mae: 0.2401
# Epoch 170/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0932 - mae: 0.2147 - val_loss: 0.1188 - val_mae: 0.2331
# Epoch 171/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.1011 - mae: 0.2129 - val_loss: 0.1109 - val_mae: 0.2339
# Epoch 172/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.0950 - mae: 0.2082 - val_loss: 0.1083 - val_mae: 0.2358
# Epoch 173/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0922 - mae: 0.2122 - val_loss: 0.1084 - val_mae: 0.2361
# Epoch 174/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0915 - mae: 0.2088 - val_loss: 0.1082 - val_mae: 0.2344
# Epoch 175/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.0901 - mae: 0.2077 - val_loss: 0.1076 - val_mae: 0.2326
# Epoch 176/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.0901 - mae: 0.2041 - val_loss: 0.1071 - val_mae: 0.2334
# Epoch 177/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0885 - mae: 0.2056 - val_loss: 0.1067 - val_mae: 0.2335
# Epoch 178/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0881 - mae: 0.2068 - val_loss: 0.1063 - val_mae: 0.2313
# Epoch 179/500
# 113/113 [==============================] - 0s 267us/step - loss: 0.0879 - mae: 0.2047 - val_loss: 0.1048 - val_mae: 0.2318
# Epoch 180/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0867 - mae: 0.2068 - val_loss: 0.1057 - val_mae: 0.2318
# Epoch 181/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0862 - mae: 0.2046 - val_loss: 0.1060 - val_mae: 0.2318
# Epoch 182/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0863 - mae: 0.2015 - val_loss: 0.1058 - val_mae: 0.2288
# Epoch 183/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0865 - mae: 0.1960 - val_loss: 0.1046 - val_mae: 0.2299
# Epoch 184/500
# 113/113 [==============================] - 0s 254us/step - loss: 0.0850 - mae: 0.2023 - val_loss: 0.1037 - val_mae: 0.2289
# Epoch 185/500
# 113/113 [==============================] - 0s 250us/step - loss: 0.0847 - mae: 0.2002 - val_loss: 0.1032 - val_mae: 0.2278
# Epoch 186/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0838 - mae: 0.1987 - val_loss: 0.1030 - val_mae: 0.2304
# Epoch 187/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.0836 - mae: 0.2039 - val_loss: 0.1026 - val_mae: 0.2270
# Epoch 188/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0833 - mae: 0.1993 - val_loss: 0.1311 - val_mae: 0.2606
# Epoch 189/500
# 113/113 [==============================] - 0s 263us/step - loss: 0.0953 - mae: 0.2282 - val_loss: 0.1136 - val_mae: 0.2475
# Epoch 190/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.0875 - mae: 0.2218 - val_loss: 0.1095 - val_mae: 0.2448
# Epoch 191/500
# 113/113 [==============================] - 0s 309us/step - loss: 0.0861 - mae: 0.2170 - val_loss: 0.1035 - val_mae: 0.2355
# Epoch 192/500
# 113/113 [==============================] - 0s 298us/step - loss: 0.0829 - mae: 0.2112 - val_loss: 0.0996 - val_mae: 0.2241
# Epoch 193/500
# 113/113 [==============================] - 0s 294us/step - loss: 0.0812 - mae: 0.2017 - val_loss: 0.0994 - val_mae: 0.2202
# Epoch 194/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.0812 - mae: 0.1942 - val_loss: 0.0992 - val_mae: 0.2193
# Epoch 195/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0800 - mae: 0.1936 - val_loss: 0.0982 - val_mae: 0.2168
# Epoch 196/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0786 - mae: 0.1896 - val_loss: 0.0972 - val_mae: 0.2145
# Epoch 197/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0787 - mae: 0.1856 - val_loss: 0.0967 - val_mae: 0.2151
# Epoch 198/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0780 - mae: 0.1886 - val_loss: 0.0967 - val_mae: 0.2143
# Epoch 199/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0781 - mae: 0.1889 - val_loss: 0.0967 - val_mae: 0.2111
# Epoch 200/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0786 - mae: 0.1831 - val_loss: 0.0951 - val_mae: 0.2107
# Epoch 201/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.0777 - mae: 0.1853 - val_loss: 0.0927 - val_mae: 0.2135
# Epoch 202/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0771 - mae: 0.1932 - val_loss: 0.0923 - val_mae: 0.2088
# Epoch 203/500
# 113/113 [==============================] - 0s 265us/step - loss: 0.0765 - mae: 0.1877 - val_loss: 0.0924 - val_mae: 0.2051
# Epoch 204/500
# 113/113 [==============================] - 0s 278us/step - loss: 0.0760 - mae: 0.1808 - val_loss: 0.0921 - val_mae: 0.2057
# Epoch 205/500
# 113/113 [==============================] - 0s 273us/step - loss: 0.0749 - mae: 0.1800 - val_loss: 0.0920 - val_mae: 0.2062
# Epoch 206/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.0762 - mae: 0.1818 - val_loss: 0.0925 - val_mae: 0.2105
# Epoch 207/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.0746 - mae: 0.1867 - val_loss: 0.0917 - val_mae: 0.2070
# Epoch 208/500
# 113/113 [==============================] - 0s 244us/step - loss: 0.0746 - mae: 0.1844 - val_loss: 0.0910 - val_mae: 0.2036
# Epoch 209/500
# 113/113 [==============================] - 0s 265us/step - loss: 0.0737 - mae: 0.1800 - val_loss: 0.0911 - val_mae: 0.2036
# Epoch 210/500
# 113/113 [==============================] - 0s 258us/step - loss: 0.0745 - mae: 0.1797 - val_loss: 0.0912 - val_mae: 0.2034
# Epoch 211/500
# 113/113 [==============================] - 0s 265us/step - loss: 0.0730 - mae: 0.1768 - val_loss: 0.0906 - val_mae: 0.2031
# Epoch 212/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0730 - mae: 0.1790 - val_loss: 0.0900 - val_mae: 0.2025
# Epoch 213/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.0726 - mae: 0.1802 - val_loss: 0.0897 - val_mae: 0.2016
# Epoch 214/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0727 - mae: 0.1765 - val_loss: 0.0894 - val_mae: 0.2020
# Epoch 215/500
# 113/113 [==============================] - 0s 279us/step - loss: 0.0720 - mae: 0.1791 - val_loss: 0.0891 - val_mae: 0.2004
# Epoch 216/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.0718 - mae: 0.1765 - val_loss: 0.0887 - val_mae: 0.1997
# Epoch 217/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.0719 - mae: 0.1748 - val_loss: 0.0888 - val_mae: 0.2002
# Epoch 218/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.0714 - mae: 0.1732 - val_loss: 0.0886 - val_mae: 0.2009
# Epoch 219/500
# 113/113 [==============================] - 0s 256us/step - loss: 0.0711 - mae: 0.1783 - val_loss: 0.0881 - val_mae: 0.1996
# Epoch 220/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.0716 - mae: 0.1742 - val_loss: 0.0879 - val_mae: 0.2000
# Epoch 221/500
# 113/113 [==============================] - 0s 297us/step - loss: 0.0695 - mae: 0.1764 - val_loss: 0.0870 - val_mae: 0.1978
# Epoch 222/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.0696 - mae: 0.1728 - val_loss: 0.0873 - val_mae: 0.2018
# Epoch 223/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0695 - mae: 0.1801 - val_loss: 0.0863 - val_mae: 0.2017
# Epoch 224/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0689 - mae: 0.1804 - val_loss: 0.0856 - val_mae: 0.1988
# Epoch 225/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.0686 - mae: 0.1761 - val_loss: 0.0856 - val_mae: 0.1986
# Epoch 226/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0680 - mae: 0.1753 - val_loss: 0.0858 - val_mae: 0.1978
# Epoch 227/500
# 113/113 [==============================] - 0s 250us/step - loss: 0.0680 - mae: 0.1717 - val_loss: 0.0859 - val_mae: 0.1980
# Epoch 228/500
# 113/113 [==============================] - 0s 261us/step - loss: 0.0675 - mae: 0.1724 - val_loss: 0.0855 - val_mae: 0.1974
# Epoch 229/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0672 - mae: 0.1728 - val_loss: 0.0850 - val_mae: 0.1964
# Epoch 230/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.0670 - mae: 0.1720 - val_loss: 0.0840 - val_mae: 0.1950
# Epoch 231/500
# 113/113 [==============================] - 0s 292us/step - loss: 0.0667 - mae: 0.1711 - val_loss: 0.0839 - val_mae: 0.1949
# Epoch 232/500
# 113/113 [==============================] - 0s 297us/step - loss: 0.0673 - mae: 0.1703 - val_loss: 0.0873 - val_mae: 0.1875
# Epoch 233/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0711 - mae: 0.1640 - val_loss: 0.0836 - val_mae: 0.1887
# Epoch 234/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0680 - mae: 0.1640 - val_loss: 0.0828 - val_mae: 0.1901
# Epoch 235/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0667 - mae: 0.1652 - val_loss: 0.0827 - val_mae: 0.1976
# Epoch 236/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0653 - mae: 0.1773 - val_loss: 0.0820 - val_mae: 0.1941
# Epoch 237/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.0652 - mae: 0.1698 - val_loss: 0.0813 - val_mae: 0.1912
# Epoch 238/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.0648 - mae: 0.1654 - val_loss: 0.0810 - val_mae: 0.1912
# Epoch 239/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.0649 - mae: 0.1664 - val_loss: 0.0809 - val_mae: 0.1903
# Epoch 240/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0650 - mae: 0.1654 - val_loss: 0.1087 - val_mae: 0.2226
# Epoch 241/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0747 - mae: 0.1942 - val_loss: 0.1076 - val_mae: 0.2191
# Epoch 242/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0730 - mae: 0.1888 - val_loss: 0.0909 - val_mae: 0.2035
# Epoch 243/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0676 - mae: 0.1802 - val_loss: 0.0856 - val_mae: 0.1981
# Epoch 244/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0654 - mae: 0.1756 - val_loss: 0.0820 - val_mae: 0.1932
# Epoch 245/500
# 113/113 [==============================] - 0s 278us/step - loss: 0.0637 - mae: 0.1708 - val_loss: 0.0809 - val_mae: 0.1916
# Epoch 246/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0625 - mae: 0.1683 - val_loss: 0.0799 - val_mae: 0.1888
# Epoch 247/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.0627 - mae: 0.1637 - val_loss: 0.0799 - val_mae: 0.1891
# Epoch 248/500
# 113/113 [==============================] - 0s 318us/step - loss: 0.0624 - mae: 0.1635 - val_loss: 0.0797 - val_mae: 0.1894
# Epoch 249/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0620 - mae: 0.1666 - val_loss: 0.0792 - val_mae: 0.1887
# Epoch 250/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.0619 - mae: 0.1639 - val_loss: 0.0791 - val_mae: 0.1889
# Epoch 251/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.0616 - mae: 0.1653 - val_loss: 0.0791 - val_mae: 0.1899
# Epoch 252/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.0624 - mae: 0.1679 - val_loss: 0.0793 - val_mae: 0.1904
# Epoch 253/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0611 - mae: 0.1628 - val_loss: 0.0789 - val_mae: 0.1901
# Epoch 254/500
# 113/113 [==============================] - 0s 267us/step - loss: 0.0612 - mae: 0.1652 - val_loss: 0.0902 - val_mae: 0.2110
# Epoch 255/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.0665 - mae: 0.1880 - val_loss: 0.0816 - val_mae: 0.1976
# Epoch 256/500
# 113/113 [==============================] - 0s 292us/step - loss: 0.0621 - mae: 0.1775 - val_loss: 0.0782 - val_mae: 0.1907
# Epoch 257/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0616 - mae: 0.1639 - val_loss: 0.0777 - val_mae: 0.1898
# Epoch 258/500
# 113/113 [==============================] - 0s 291us/step - loss: 0.0593 - mae: 0.1644 - val_loss: 0.0771 - val_mae: 0.1885
# Epoch 259/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0594 - mae: 0.1652 - val_loss: 0.0768 - val_mae: 0.1882
# Epoch 260/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0591 - mae: 0.1624 - val_loss: 0.0755 - val_mae: 0.1867
# Epoch 261/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.0590 - mae: 0.1699 - val_loss: 0.0751 - val_mae: 0.1851
# Epoch 262/500
# 113/113 [==============================] - 0s 273us/step - loss: 0.0589 - mae: 0.1660 - val_loss: 0.0750 - val_mae: 0.1847
# Epoch 263/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0588 - mae: 0.1642 - val_loss: 0.0750 - val_mae: 0.1849
# Epoch 264/500
# 113/113 [==============================] - 0s 274us/step - loss: 0.0582 - mae: 0.1596 - val_loss: 0.0750 - val_mae: 0.1851
# Epoch 265/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0583 - mae: 0.1593 - val_loss: 0.0753 - val_mae: 0.1860
# Epoch 266/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0578 - mae: 0.1623 - val_loss: 0.0779 - val_mae: 0.1920
# Epoch 267/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.0592 - mae: 0.1697 - val_loss: 0.0790 - val_mae: 0.1950
# Epoch 268/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0606 - mae: 0.1726 - val_loss: 0.0744 - val_mae: 0.1849
# Epoch 269/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.0584 - mae: 0.1619 - val_loss: 0.0742 - val_mae: 0.1851
# Epoch 270/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.0592 - mae: 0.1623 - val_loss: 0.0738 - val_mae: 0.1829
# Epoch 271/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0571 - mae: 0.1584 - val_loss: 0.0746 - val_mae: 0.1852
# Epoch 272/500
# 113/113 [==============================] - 0s 305us/step - loss: 0.0571 - mae: 0.1573 - val_loss: 0.0756 - val_mae: 0.1821
# Epoch 273/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0584 - mae: 0.1554 - val_loss: 0.0736 - val_mae: 0.1824
# Epoch 274/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0566 - mae: 0.1562 - val_loss: 0.0737 - val_mae: 0.1815
# Epoch 275/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.0568 - mae: 0.1576 - val_loss: 0.0745 - val_mae: 0.1839
# Epoch 276/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0567 - mae: 0.1542 - val_loss: 0.0730 - val_mae: 0.1820
# Epoch 277/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0561 - mae: 0.1562 - val_loss: 0.0727 - val_mae: 0.1803
# Epoch 278/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.0572 - mae: 0.1567 - val_loss: 0.0728 - val_mae: 0.1818
# Epoch 279/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0555 - mae: 0.1546 - val_loss: 0.0728 - val_mae: 0.1824
# Epoch 280/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.0550 - mae: 0.1577 - val_loss: 0.0741 - val_mae: 0.1846
# Epoch 281/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.0555 - mae: 0.1566 - val_loss: 0.0776 - val_mae: 0.1754
# Epoch 282/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.0598 - mae: 0.1495 - val_loss: 0.0722 - val_mae: 0.1767
# Epoch 283/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.0561 - mae: 0.1537 - val_loss: 0.0724 - val_mae: 0.1763
# Epoch 284/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0566 - mae: 0.1531 - val_loss: 0.0722 - val_mae: 0.1797
# Epoch 285/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.0549 - mae: 0.1518 - val_loss: 0.0726 - val_mae: 0.1830
# Epoch 286/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0559 - mae: 0.1563 - val_loss: 0.0719 - val_mae: 0.1825
# Epoch 287/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.0542 - mae: 0.1548 - val_loss: 0.1024 - val_mae: 0.2129
# Epoch 288/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.0669 - mae: 0.1847 - val_loss: 0.0808 - val_mae: 0.1941
# Epoch 289/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0571 - mae: 0.1687 - val_loss: 0.0743 - val_mae: 0.1865
# Epoch 290/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.0552 - mae: 0.1613 - val_loss: 0.0724 - val_mae: 0.1818
# Epoch 291/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0550 - mae: 0.1561 - val_loss: 0.0721 - val_mae: 0.1811
# Epoch 292/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.0544 - mae: 0.1539 - val_loss: 0.0725 - val_mae: 0.1790
# Epoch 293/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0549 - mae: 0.1512 - val_loss: 0.0782 - val_mae: 0.1740
# Epoch 294/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.0598 - mae: 0.1477 - val_loss: 0.0706 - val_mae: 0.1733
# Epoch 295/500
# 113/113 [==============================] - 0s 306us/step - loss: 0.0545 - mae: 0.1495 - val_loss: 0.0689 - val_mae: 0.1750
# Epoch 296/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.0532 - mae: 0.1546 - val_loss: 0.0688 - val_mae: 0.1752
# Epoch 297/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0529 - mae: 0.1502 - val_loss: 0.0688 - val_mae: 0.1771
# Epoch 298/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.0522 - mae: 0.1546 - val_loss: 0.0692 - val_mae: 0.1780
# Epoch 299/500
# 113/113 [==============================] - 0s 290us/step - loss: 0.0522 - mae: 0.1535 - val_loss: 0.0695 - val_mae: 0.1779
# Epoch 300/500
# 113/113 [==============================] - 0s 297us/step - loss: 0.0523 - mae: 0.1546 - val_loss: 0.0700 - val_mae: 0.1790
# Epoch 301/500
# 113/113 [==============================] - 0s 293us/step - loss: 0.0530 - mae: 0.1550 - val_loss: 0.0698 - val_mae: 0.1778
# Epoch 302/500
# 113/113 [==============================] - 0s 292us/step - loss: 0.0525 - mae: 0.1500 - val_loss: 0.0686 - val_mae: 0.1766
# Epoch 303/500
# 113/113 [==============================] - 0s 290us/step - loss: 0.0526 - mae: 0.1556 - val_loss: 0.0684 - val_mae: 0.1759
# Epoch 304/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0516 - mae: 0.1541 - val_loss: 0.0682 - val_mae: 0.1751
# Epoch 305/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.0512 - mae: 0.1516 - val_loss: 0.0686 - val_mae: 0.1746
# Epoch 306/500
# 113/113 [==============================] - 0s 281us/step - loss: 0.0517 - mae: 0.1497 - val_loss: 0.0687 - val_mae: 0.1760
# Epoch 307/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0515 - mae: 0.1534 - val_loss: 0.0726 - val_mae: 0.1694
# Epoch 308/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.0550 - mae: 0.1464 - val_loss: 0.0667 - val_mae: 0.1733
# Epoch 309/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.0515 - mae: 0.1524 - val_loss: 0.0668 - val_mae: 0.1737
# Epoch 310/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.0514 - mae: 0.1507 - val_loss: 0.0900 - val_mae: 0.2022
# Epoch 311/500
# 113/113 [==============================] - 0s 280us/step - loss: 0.0614 - mae: 0.1769 - val_loss: 0.0670 - val_mae: 0.1746
# Epoch 312/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0500 - mae: 0.1513 - val_loss: 0.0671 - val_mae: 0.1751
# Epoch 313/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0503 - mae: 0.1532 - val_loss: 0.0671 - val_mae: 0.1733
# Epoch 314/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0510 - mae: 0.1500 - val_loss: 0.0965 - val_mae: 0.2054
# Epoch 315/500
# 113/113 [==============================] - 0s 283us/step - loss: 0.0638 - mae: 0.1787 - val_loss: 0.1058 - val_mae: 0.2106
# Epoch 316/500
# 113/113 [==============================] - 0s 293us/step - loss: 0.0665 - mae: 0.1804 - val_loss: 0.0793 - val_mae: 0.1907
# Epoch 317/500
# 113/113 [==============================] - 0s 332us/step - loss: 0.0539 - mae: 0.1623 - val_loss: 0.0715 - val_mae: 0.1833
# Epoch 318/500
# 113/113 [==============================] - 0s 292us/step - loss: 0.0546 - mae: 0.1685 - val_loss: 0.0687 - val_mae: 0.1869
# Epoch 319/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.0556 - mae: 0.1750 - val_loss: 0.0641 - val_mae: 0.1724
# Epoch 320/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0514 - mae: 0.1602 - val_loss: 0.0640 - val_mae: 0.1711
# Epoch 321/500
# 113/113 [==============================] - 0s 284us/step - loss: 0.0502 - mae: 0.1595 - val_loss: 0.0638 - val_mae: 0.1687
# Epoch 322/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.0496 - mae: 0.1531 - val_loss: 0.0670 - val_mae: 0.1661
# Epoch 323/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.0522 - mae: 0.1491 - val_loss: 0.0655 - val_mae: 0.1682
# Epoch 324/500
# 113/113 [==============================] - 0s 293us/step - loss: 0.0498 - mae: 0.1439 - val_loss: 0.0650 - val_mae: 0.1708
# Epoch 325/500
# 113/113 [==============================] - 0s 294us/step - loss: 0.0487 - mae: 0.1482 - val_loss: 0.0650 - val_mae: 0.1716
# Epoch 326/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.0487 - mae: 0.1524 - val_loss: 0.0650 - val_mae: 0.1713
# Epoch 327/500
# 113/113 [==============================] - 0s 287us/step - loss: 0.0494 - mae: 0.1515 - val_loss: 0.0647 - val_mae: 0.1711
# Epoch 328/500
# 113/113 [==============================] - 0s 294us/step - loss: 0.0489 - mae: 0.1517 - val_loss: 0.0647 - val_mae: 0.1707
# Epoch 329/500
# 113/113 [==============================] - 0s 295us/step - loss: 0.0481 - mae: 0.1475 - val_loss: 0.0647 - val_mae: 0.1715
# Epoch 330/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0489 - mae: 0.1495 - val_loss: 0.0656 - val_mae: 0.1734
# Epoch 331/500
# 113/113 [==============================] - 0s 293us/step - loss: 0.0479 - mae: 0.1486 - val_loss: 0.0682 - val_mae: 0.1706
# Epoch 332/500
# 113/113 [==============================] - 0s 286us/step - loss: 0.0499 - mae: 0.1428 - val_loss: 0.0638 - val_mae: 0.1687
# Epoch 333/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0480 - mae: 0.1478 - val_loss: 0.0644 - val_mae: 0.1686
# Epoch 334/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0484 - mae: 0.1448 - val_loss: 0.0643 - val_mae: 0.1694
# Epoch 335/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0481 - mae: 0.1468 - val_loss: 0.0641 - val_mae: 0.1702
# Epoch 336/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0482 - mae: 0.1503 - val_loss: 0.0641 - val_mae: 0.1697
# Epoch 337/500
# 113/113 [==============================] - 0s 265us/step - loss: 0.0476 - mae: 0.1465 - val_loss: 0.0630 - val_mae: 0.1690
# Epoch 338/500
# 113/113 [==============================] - 0s 282us/step - loss: 0.0482 - mae: 0.1491 - val_loss: 0.0630 - val_mae: 0.1680
# Epoch 339/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0481 - mae: 0.1502 - val_loss: 0.0634 - val_mae: 0.1681
# Epoch 340/500
# 113/113 [==============================] - 0s 277us/step - loss: 0.0473 - mae: 0.1474 - val_loss: 0.0636 - val_mae: 0.1679
# Epoch 341/500
# 113/113 [==============================] - 0s 323us/step - loss: 0.0479 - mae: 0.1453 - val_loss: 0.0638 - val_mae: 0.1703
# Epoch 342/500
# 113/113 [==============================] - 0s 289us/step - loss: 0.0466 - mae: 0.1486 - val_loss: 0.0641 - val_mae: 0.1709
# Epoch 343/500
# 113/113 [==============================] - 0s 288us/step - loss: 0.0467 - mae: 0.1464 - val_loss: 0.0640 - val_mae: 0.1710
# Epoch 344/500
# 113/113 [==============================] - 0s 290us/step - loss: 0.0465 - mae: 0.1475 - val_loss: 0.0635 - val_mae: 0.1698
# Epoch 345/500
# 113/113 [==============================] - 0s 276us/step - loss: 0.0463 - mae: 0.1471 - val_loss: 0.0629 - val_mae: 0.1686
# Epoch 346/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.0467 - mae: 0.1496 - val_loss: 0.0658 - val_mae: 0.1652
# Epoch 347/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.0495 - mae: 0.1403 - val_loss: 0.0631 - val_mae: 0.1669
# Epoch 348/500
# 113/113 [==============================] - 0s 267us/step - loss: 0.0476 - mae: 0.1449 - val_loss: 0.0626 - val_mae: 0.1670
# Epoch 349/500
# 113/113 [==============================] - 0s 279us/step - loss: 0.0463 - mae: 0.1457 - val_loss: 0.0636 - val_mae: 0.1650
# Epoch 350/500
# 113/113 [==============================] - 0s 285us/step - loss: 0.0475 - mae: 0.1434 - val_loss: 0.0633 - val_mae: 0.1665
# Epoch 351/500
# ...
# Epoch 385/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.0453 - mae: 0.1369 - val_loss: 0.0619 - val_mae: 0.1599
# Epoch 386/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0448 - mae: 0.1395 - val_loss: 0.0656 - val_mae: 0.1589
# Epoch 387/500
# 113/113 [==============================] - 0s 346us/step - loss: 0.0472 - mae: 0.1313 - val_loss: 0.1124 - val_mae: 0.2080
# Epoch 388/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0643 - mae: 0.1685 - val_loss: 0.0725 - val_mae: 0.1746
# Epoch 389/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0493 - mae: 0.1484 - val_loss: 0.0660 - val_mae: 0.1675
# Epoch 390/500
# 113/113 [==============================] - 0s 252us/step - loss: 0.0459 - mae: 0.1428 - val_loss: 0.0634 - val_mae: 0.1636
# Epoch 391/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.0452 - mae: 0.1403 - val_loss: 0.0627 - val_mae: 0.1623
# Epoch 392/500
# 113/113 [==============================] - 0s 255us/step - loss: 0.0446 - mae: 0.1371 - val_loss: 0.0642 - val_mae: 0.1664
# Epoch 393/500
# 113/113 [==============================] - 0s 256us/step - loss: 0.0459 - mae: 0.1442 - val_loss: 0.0625 - val_mae: 0.1636
# Epoch 394/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0451 - mae: 0.1434 - val_loss: 0.0618 - val_mae: 0.1603
# Epoch 395/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0449 - mae: 0.1381 - val_loss: 0.0613 - val_mae: 0.1730
# Epoch 396/500
# 113/113 [==============================] - 0s 251us/step - loss: 0.0501 - mae: 0.1582 - val_loss: 0.0698 - val_mae: 0.1573
# Epoch 397/500
# 113/113 [==============================] - 0s 251us/step - loss: 0.0557 - mae: 0.1423 - val_loss: 0.0616 - val_mae: 0.1520
# Epoch 398/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.0474 - mae: 0.1376 - val_loss: 0.0606 - val_mae: 0.1536
# Epoch 399/500
# 113/113 [==============================] - 0s 241us/step - loss: 0.0461 - mae: 0.1383 - val_loss: 0.0605 - val_mae: 0.1554
# Epoch 400/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0447 - mae: 0.1382 - val_loss: 0.0608 - val_mae: 0.1570
# Epoch 401/500
# 113/113 [==============================] - 0s 254us/step - loss: 0.0445 - mae: 0.1358 - val_loss: 0.0612 - val_mae: 0.1586
# Epoch 402/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0450 - mae: 0.1364 - val_loss: 0.0606 - val_mae: 0.1593
# Epoch 403/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.0441 - mae: 0.1402 - val_loss: 0.0607 - val_mae: 0.1593
# Epoch 404/500
# 113/113 [==============================] - 0s 254us/step - loss: 0.0437 - mae: 0.1394 - val_loss: 0.0680 - val_mae: 0.1591
# Epoch 405/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.0489 - mae: 0.1317 - val_loss: 0.0616 - val_mae: 0.1546
# Epoch 406/500
# 113/113 [==============================] - 0s 324us/step - loss: 0.0454 - mae: 0.1350 - val_loss: 0.0603 - val_mae: 0.1559
# Epoch 407/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.0444 - mae: 0.1372 - val_loss: 0.0607 - val_mae: 0.1576
# Epoch 408/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0438 - mae: 0.1362 - val_loss: 0.0609 - val_mae: 0.1589
# Epoch 409/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.0445 - mae: 0.1403 - val_loss: 0.0609 - val_mae: 0.1582
# Epoch 410/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0439 - mae: 0.1372 - val_loss: 0.0642 - val_mae: 0.1577
# Epoch 411/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0451 - mae: 0.1314 - val_loss: 0.0636 - val_mae: 0.1615
# Epoch 412/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0445 - mae: 0.1349 - val_loss: 0.0630 - val_mae: 0.1616
# Epoch 413/500
# 113/113 [==============================] - 0s 248us/step - loss: 0.0440 - mae: 0.1338 - val_loss: 0.0615 - val_mae: 0.1610
# Epoch 414/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0434 - mae: 0.1385 - val_loss: 0.0613 - val_mae: 0.1593
# Epoch 415/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0432 - mae: 0.1357 - val_loss: 0.0612 - val_mae: 0.1597
# Epoch 416/500
# 113/113 [==============================] - 0s 292us/step - loss: 0.0439 - mae: 0.1358 - val_loss: 0.0615 - val_mae: 0.1601
# Epoch 417/500
# 113/113 [==============================] - 0s 249us/step - loss: 0.0434 - mae: 0.1366 - val_loss: 0.0613 - val_mae: 0.1596
# Epoch 418/500
# 113/113 [==============================] - 0s 250us/step - loss: 0.0433 - mae: 0.1342 - val_loss: 0.0611 - val_mae: 0.1599
# Epoch 419/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0439 - mae: 0.1358 - val_loss: 0.0610 - val_mae: 0.1587
# Epoch 420/500
# 113/113 [==============================] - 0s 275us/step - loss: 0.0430 - mae: 0.1355 - val_loss: 0.0624 - val_mae: 0.1562
# Epoch 421/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0452 - mae: 0.1354 - val_loss: 0.0619 - val_mae: 0.1558
# Epoch 422/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.0444 - mae: 0.1332 - val_loss: 0.0668 - val_mae: 0.1587
# Epoch 423/500
# 113/113 [==============================] - 0s 252us/step - loss: 0.0477 - mae: 0.1320 - val_loss: 0.0614 - val_mae: 0.1563
# Epoch 424/500
# 113/113 [==============================] - 0s 249us/step - loss: 0.0439 - mae: 0.1303 - val_loss: 0.0627 - val_mae: 0.1623
# Epoch 425/500
# 113/113 [==============================] - 0s 249us/step - loss: 0.0437 - mae: 0.1354 - val_loss: 0.0622 - val_mae: 0.1615
# Epoch 426/500
# 113/113 [==============================] - 0s 256us/step - loss: 0.0436 - mae: 0.1361 - val_loss: 0.0619 - val_mae: 0.1607
# Epoch 427/500
# 113/113 [==============================] - 0s 245us/step - loss: 0.0433 - mae: 0.1334 - val_loss: 0.0616 - val_mae: 0.1608
# Epoch 428/500
# 113/113 [==============================] - 0s 263us/step - loss: 0.0430 - mae: 0.1348 - val_loss: 0.0603 - val_mae: 0.1585
# Epoch 429/500
# 113/113 [==============================] - 0s 261us/step - loss: 0.0432 - mae: 0.1383 - val_loss: 0.0603 - val_mae: 0.1572
# Epoch 430/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0437 - mae: 0.1364 - val_loss: 0.0652 - val_mae: 0.1664
# Epoch 431/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0435 - mae: 0.1317 - val_loss: 0.0638 - val_mae: 0.1658
# Epoch 432/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0442 - mae: 0.1353 - val_loss: 0.1077 - val_mae: 0.2081
# Epoch 433/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0622 - mae: 0.1627 - val_loss: 0.0693 - val_mae: 0.1723
# Epoch 434/500
# 113/113 [==============================] - 0s 246us/step - loss: 0.0457 - mae: 0.1420 - val_loss: 0.0613 - val_mae: 0.1591
# Epoch 435/500
# 113/113 [==============================] - 0s 340us/step - loss: 0.0447 - mae: 0.1403 - val_loss: 0.0668 - val_mae: 0.1588
# Epoch 436/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0474 - mae: 0.1320 - val_loss: 0.0606 - val_mae: 0.1526
# Epoch 437/500
# 113/113 [==============================] - 0s 269us/step - loss: 0.0437 - mae: 0.1291 - val_loss: 0.0984 - val_mae: 0.1970
# Epoch 438/500
# 113/113 [==============================] - 0s 263us/step - loss: 0.0620 - mae: 0.1658 - val_loss: 0.0674 - val_mae: 0.1684
# Epoch 439/500
# 113/113 [==============================] - 0s 240us/step - loss: 0.0466 - mae: 0.1432 - val_loss: 0.0620 - val_mae: 0.1604
# Epoch 440/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.0443 - mae: 0.1402 - val_loss: 0.0602 - val_mae: 0.1564
# Epoch 441/500
# 113/113 [==============================] - 0s 249us/step - loss: 0.0443 - mae: 0.1345 - val_loss: 0.0601 - val_mae: 0.1569
# Epoch 442/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0431 - mae: 0.1341 - val_loss: 0.0683 - val_mae: 0.1752
# Epoch 443/500
# 113/113 [==============================] - 0s 258us/step - loss: 0.0468 - mae: 0.1500 - val_loss: 0.0616 - val_mae: 0.1613
# Epoch 444/500
# 113/113 [==============================] - 0s 274us/step - loss: 0.0435 - mae: 0.1389 - val_loss: 0.0626 - val_mae: 0.1625
# Epoch 445/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.0425 - mae: 0.1347 - val_loss: 0.0622 - val_mae: 0.1625
# Epoch 446/500
# 113/113 [==============================] - 0s 251us/step - loss: 0.0434 - mae: 0.1346 - val_loss: 0.0627 - val_mae: 0.1644
# Epoch 447/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.0427 - mae: 0.1378 - val_loss: 0.0614 - val_mae: 0.1604
# Epoch 448/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0426 - mae: 0.1346 - val_loss: 0.0614 - val_mae: 0.1593
# Epoch 449/500
# 113/113 [==============================] - 0s 254us/step - loss: 0.0428 - mae: 0.1326 - val_loss: 0.0611 - val_mae: 0.1596
# Epoch 450/500
# 113/113 [==============================] - 0s 251us/step - loss: 0.0431 - mae: 0.1340 - val_loss: 0.0605 - val_mae: 0.1575
# Epoch 451/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.0420 - mae: 0.1319 - val_loss: 0.0582 - val_mae: 0.1544
# Epoch 452/500
# 113/113 [==============================] - 0s 251us/step - loss: 0.0424 - mae: 0.1365 - val_loss: 0.0580 - val_mae: 0.1538
# Epoch 453/500
# 113/113 [==============================] - 0s 272us/step - loss: 0.0421 - mae: 0.1356 - val_loss: 0.0592 - val_mae: 0.1567
# Epoch 454/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.0422 - mae: 0.1376 - val_loss: 0.0590 - val_mae: 0.1558
# Epoch 455/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0438 - mae: 0.1347 - val_loss: 0.0597 - val_mae: 0.1574
# Epoch 456/500
# 113/113 [==============================] - 0s 256us/step - loss: 0.0422 - mae: 0.1351 - val_loss: 0.0581 - val_mae: 0.1550
# Epoch 457/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0440 - mae: 0.1383 - val_loss: 0.0597 - val_mae: 0.1588
# Epoch 458/500
# 113/113 [==============================] - 0s 245us/step - loss: 0.0424 - mae: 0.1389 - val_loss: 0.0589 - val_mae: 0.1558
# Epoch 459/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0422 - mae: 0.1361 - val_loss: 0.0591 - val_mae: 0.1560
# Epoch 460/500
# 113/113 [==============================] - 0s 256us/step - loss: 0.0425 - mae: 0.1355 - val_loss: 0.0598 - val_mae: 0.1563
# Epoch 461/500
# 113/113 [==============================] - 0s 245us/step - loss: 0.0424 - mae: 0.1333 - val_loss: 0.0604 - val_mae: 0.1596
# Epoch 462/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0419 - mae: 0.1360 - val_loss: 0.0600 - val_mae: 0.1551
# Epoch 463/500
# 113/113 [==============================] - 0s 253us/step - loss: 0.0424 - mae: 0.1331 - val_loss: 0.0596 - val_mae: 0.1552
# Epoch 464/500
# 113/113 [==============================] - 0s 261us/step - loss: 0.0425 - mae: 0.1344 - val_loss: 0.0595 - val_mae: 0.1551
# Epoch 465/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0422 - mae: 0.1327 - val_loss: 0.0597 - val_mae: 0.1561
# Epoch 466/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0416 - mae: 0.1347 - val_loss: 0.0595 - val_mae: 0.1553
# Epoch 467/500
# 113/113 [==============================] - 0s 254us/step - loss: 0.0422 - mae: 0.1335 - val_loss: 0.0604 - val_mae: 0.1546
# Epoch 468/500
# 113/113 [==============================] - 0s 251us/step - loss: 0.0424 - mae: 0.1314 - val_loss: 0.0595 - val_mae: 0.1545
# Epoch 469/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0419 - mae: 0.1315 - val_loss: 0.0654 - val_mae: 0.1567
# Epoch 470/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0455 - mae: 0.1281 - val_loss: 0.0629 - val_mae: 0.1550
# Epoch 471/500
# 113/113 [==============================] - 0s 257us/step - loss: 0.0437 - mae: 0.1290 - val_loss: 0.0621 - val_mae: 0.1583
# Epoch 472/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.0419 - mae: 0.1280 - val_loss: 0.0626 - val_mae: 0.1619
# Epoch 473/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0425 - mae: 0.1319 - val_loss: 0.0617 - val_mae: 0.1602
# Epoch 474/500
# 113/113 [==============================] - 0s 271us/step - loss: 0.0421 - mae: 0.1331 - val_loss: 0.0607 - val_mae: 0.1580
# Epoch 475/500
# 113/113 [==============================] - 0s 245us/step - loss: 0.0420 - mae: 0.1314 - val_loss: 0.0621 - val_mae: 0.1614
# Epoch 476/500
# 113/113 [==============================] - 0s 266us/step - loss: 0.0423 - mae: 0.1320 - val_loss: 0.0614 - val_mae: 0.1601
# Epoch 477/500
# 113/113 [==============================] - 0s 252us/step - loss: 0.0424 - mae: 0.1346 - val_loss: 0.0602 - val_mae: 0.1583
# Epoch 478/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.0413 - mae: 0.1333 - val_loss: 0.0600 - val_mae: 0.1572
# Epoch 479/500
# 113/113 [==============================] - 0s 263us/step - loss: 0.0413 - mae: 0.1336 - val_loss: 0.0597 - val_mae: 0.1559
# Epoch 480/500
# 113/113 [==============================] - 0s 256us/step - loss: 0.0422 - mae: 0.1307 - val_loss: 0.0601 - val_mae: 0.1584
# Epoch 481/500
# 113/113 [==============================] - 0s 261us/step - loss: 0.0414 - mae: 0.1327 - val_loss: 0.0598 - val_mae: 0.1573
# Epoch 482/500
# 113/113 [==============================] - 0s 258us/step - loss: 0.0411 - mae: 0.1344 - val_loss: 0.0593 - val_mae: 0.1547
# Epoch 483/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0419 - mae: 0.1326 - val_loss: 0.0593 - val_mae: 0.1550
# Epoch 484/500
# 113/113 [==============================] - 0s 244us/step - loss: 0.0418 - mae: 0.1313 - val_loss: 0.0583 - val_mae: 0.1541
# Epoch 485/500
# 113/113 [==============================] - 0s 251us/step - loss: 0.0422 - mae: 0.1355 - val_loss: 0.0593 - val_mae: 0.1689
# Epoch 486/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.0482 - mae: 0.1507 - val_loss: 0.0566 - val_mae: 0.1562
# Epoch 487/500
# 113/113 [==============================] - 0s 259us/step - loss: 0.0454 - mae: 0.1452 - val_loss: 0.0776 - val_mae: 0.1802
# Epoch 488/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0494 - mae: 0.1563 - val_loss: 0.0594 - val_mae: 0.1569
# Epoch 489/500
# 113/113 [==============================] - 0s 264us/step - loss: 0.0437 - mae: 0.1437 - val_loss: 0.0569 - val_mae: 0.1508
# Epoch 490/500
# 113/113 [==============================] - 0s 261us/step - loss: 0.0425 - mae: 0.1353 - val_loss: 0.0578 - val_mae: 0.1530
# Epoch 491/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0420 - mae: 0.1375 - val_loss: 0.0577 - val_mae: 0.1527
# Epoch 492/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0410 - mae: 0.1339 - val_loss: 0.0609 - val_mae: 0.1614
# Epoch 493/500
# 113/113 [==============================] - 0s 252us/step - loss: 0.0425 - mae: 0.1371 - val_loss: 0.0591 - val_mae: 0.1572
# Epoch 494/500
# 113/113 [==============================] - 0s 270us/step - loss: 0.0416 - mae: 0.1347 - val_loss: 0.0584 - val_mae: 0.1552
# Epoch 495/500
# 113/113 [==============================] - 0s 250us/step - loss: 0.0413 - mae: 0.1329 - val_loss: 0.1182 - val_mae: 0.2125
# Epoch 496/500
# 113/113 [==============================] - 0s 268us/step - loss: 0.0652 - mae: 0.1668 - val_loss: 0.0681 - val_mae: 0.1681
# Epoch 497/500
# 113/113 [==============================] - 0s 262us/step - loss: 0.0453 - mae: 0.1427 - val_loss: 0.0611 - val_mae: 0.1596
# Epoch 498/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0418 - mae: 0.1366 - val_loss: 0.0589 - val_mae: 0.1558
# Epoch 499/500
# 113/113 [==============================] - 0s 260us/step - loss: 0.0412 - mae: 0.1342 - val_loss: 0.0592 - val_mae: 0.1563
# Epoch 500/500
# 113/113 [==============================] - 0s 250us/step - loss: 0.0408 - mae: 0.1329 - val_loss: 0.0589 - val_mae: 0.1554

# %%
"""model_path = os.path.join(data_folder, "model")
# Import the exported model in future runs using the greyed out line below (remove the hastag)
model = pickle.load(open(os.path.join(model_path, "ReinNN.pkl"), "rb"))"""
# Out:
# 'model_path = os.path.join(data_folder, "model")\n# Import the exported model in future runs using the greyed out line below (remove the hastag)\nmodel = pickle.load(open(os.path.join(model_path, "ReinNN.pkl"), "rb"))'

# %%
for i in hml_list:

    ## Import the train and test dataframes. Drop the 'dateRep' column as it is not need for the prediciton.
    train_X = pd.read_csv(os.path.join(data_path, "train", 'train_x_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1).filter(parameter_list, axis=1)
    train_y = pd.read_csv(os.path.join(data_path, "train", 'train_y_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)
    ## '.sample' randomises the dataframe as the validation test below will take the bottom 20% of the data
    ## 'frac=1' means it will use all the data and 'random_state=1' keeps the resample consistent between df's
    test_x = pd.read_csv(os.path.join(data_path, "test", 'test_x_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1).filter(parameter_list, axis=1)
    test_y = pd.read_csv(os.path.join(data_path, "test", 'test_y_' + i + '.csv'), index_col=0).sample(frac=1, random_state=1)

    ## Initialise Scalars so that data is normalised to 1.
    sc_x = StandardScaler()
    sc_y = StandardScaler()
    ## Normalise the data using the scalar.
    X_train = sc_x.fit_transform(train_X)
    X_test = sc_x.transform(test_x)

    y_train = sc_y.fit_transform(train_y)
    y_test = sc_y.transform(test_y)

    # Calculate the predicted deaths according to the neural net model
    test_x["gold_pred"] = sc_y.inverse_transform(classifier.predict(X_test))
    # Calculate the predicted deaths according to the neural net model
    train_X["gold_pred"] = sc_y.inverse_transform(classifier.predict(X_train))
    #df1 = pd.concat([test_x, train_X], axis=1)
    df= train_X.merge(train_y,left_index=True, right_index=True)
    # We merge the test dataframes together
    df1 = test_x.merge(test_y, left_index=True, right_index=True)
    # We append the test data to the train data
    df = df.append(df1)
    
    # Again read in the 'covid19_df' as df_global
    df_global = pd.read_csv(os.path.join(os.getcwd(), "Data_Export", "gold_df_" + i + ".csv"), index_col=0)
    # Merge in the 'deaths_pred' prediction column to compare to the real data
    df_global = df_global.merge(df["gold_pred"], left_index=True, right_index=True, how='left')
    df_global.index = pd.to_datetime(df_global.index)
    
    df_global.to_csv(os.path.join(os.getcwd(), "data_export", "gold_df_" + i + ".csv"))

# %%
# Import the three complete datasets.
lmh_list = [df_global_high, df_global_mid, df_global_low]
df_global_high = pd.read_csv(os.path.join(os.getcwd(), "Data_Export", "gold_df_high.csv"), index_col=0)
df_global_high.index = pd.to_datetime(df_global_high.index)
df_global_mid = pd.read_csv(os.path.join(os.getcwd(), "Data_Export", "gold_df_mid.csv"), index_col=0)
df_global_mid.index = pd.to_datetime(df_global_mid.index)
df_global_low = pd.read_csv(os.path.join(os.getcwd(), "Data_Export", "gold_df_low.csv"), index_col=0)
df_global_low.index = pd.to_datetime(df_global_low.index)

# %%
# Compute the prediction error
df_global_high['gold_pred_error'] = df_global_high['GOLDAMGBDollarD228NLBM'] - df_global_high['gold_pred']
# Compute the cumulative error for gold
df_global_high['cumulative_error'] = df_global_high['gold_pred_error'].cumsum()

df_global_mid['gold_pred_error'] = df_global_mid['GOLDAMGBDollarD228NLBM'] - df_global_mid['gold_pred']
df_global_mid['cumulative_error'] = df_global_mid['gold_pred_error'].cumsum()
df_global_low['gold_pred_error'] = df_global_low['GOLDAMGBDollarD228NLBM'] - df_global_low['gold_pred']
df_global_low['cumulative_error'] = df_global_low['gold_pred_error'].cumsum()

# %%
# Visualising the Linear Regression results.
fig, ax1 = plt.subplots()
j = 'GOLDAMGBDollarD228NLBM'
k = 'gold_pred_error'
l = 'gold_pred'

#ax1.plot(df_global.index, df_global[k], label=k, c='mediumturquoise')
#ax1.axvline(x=dt.date(2020, 8, 1), linestyle='--', color='black', label='Real_Data_Cutoff', linewidth=1)
#ax1.axvline(x=dt.date(2016, 1, 1), linestyle=':', color='black', label='Test_Data_Cutoff', linewidth=1)

ax2 = ax1.twinx()
ax1.fill_between(df_global_high.index, df_global_low[l],  df_global_high[l], color='royalblue', alpha=0.3, label='Predicted Gold Price Range')
ax1.axvspan(dt.date(2016, 1, 1), dt.date(2020, 8, 1), alpha=0.1, color='red', label='Test Data')
ax2.plot(df_global_high.index, df_global_high[l], label='gold predicted (US $) high', c='crimson', linestyle='dashed', linewidth=1)
ax2.plot(df_global_mid.index, df_global_mid[l], label='gold predicted (US $) mid', c='orange', linestyle='dashed')
ax2.plot(df_global_low.index, df_global_low[l], label='gold predicted (US $) low', c='royalblue', linestyle='dashed', linewidth=1)
ax2.plot(df_global_high.index, df_global_high[j], label='gold (US $)', c='goldenrod')


#ax1.ylim(0, 15)
plt.title(j)
plt.xlabel('Date')
plt.grid()
ax1.legend(loc=2)
ax2.legend(loc=1)
fig.set_size_inches(18.5, 10.5)

ax1.set_xlabel('Date')
ax1.set_ylabel('Price (US $)')
ax2.set_ylabel('Price (US $)')
#plt.savefig('cumulative_error_20_countries_XGB_dpi300.jpeg', dpi=300)
# Out:
# Text(0, 0.5, 'Price (US $)')

# %%
## Calculate the mean absolute error and R2 scores for the predicted vs real test data.
print(f"Test data MAE score: {np.round(mean_absolute_error(df1.loc[df1.index < '2020-08-31'][gold_col], df1.loc[df1.index < '2020-08-31']['gold_pred']))}")
print(f"Test data R2 score: {np.round(r2_score(df1.loc[df1.index < '2020-08-31'][gold_col], df1.loc[df1.index < '2020-08-31']['gold_pred']))}")
# Out:
# Test data MAE score: 91.0
# Test data R2 score: 0.0

# %%
# Visualising the Linear Regression results.
fig, ax1 = plt.subplots()
j = 'GOLDAMGBDollarD228NLBM'
k = 'gold_pred_error'
l = 'gold_pred'

#ax1.plot(df_global.index, df_global[k], label=k, c='mediumturquoise')
#ax1.axvline(x=dt.date(2020, 8, 1), linestyle='--', color='black', label='Real_Data_Cutoff', linewidth=1)
#ax1.axvline(x=dt.date(2016, 1, 1), linestyle=':', color='black', label='Test_Data_Cutoff', linewidth=1)
ax1.axhline(y=0, color='black', label='Zero_error', linewidth=1)

ax2 = ax1.twinx()
ax2.fill_between(df_global_high.index, df_global_low[l],  df_global_high[l], color='royalblue', alpha=0.3)
ax1.axvspan(dt.date(2016, 1, 1), dt.date(2020, 8, 1), alpha=0.1, color='red')
ax2.plot(df_global_high.index, df_global_high[l], label='gold predicted (US $) high', c='crimson', linestyle='dashed', linewidth=1)
ax2.plot(df_global_mid.index, df_global_mid[l], label='gold predicted (US $) mid', c='orange', linestyle='dashed')
ax2.plot(df_global_low.index, df_global_low[l], label='gold predicted (US $) low', c='royalblue', linestyle='dashed', linewidth=1)
ax1.plot(df_global_high.index, df_global_high[k], label='gold (US $)', c='firebrick', linewidth=1)
ax2.plot(df_global_high.index, df_global_high[j], label='gold (US $)', c='goldenrod')


#ax1.ylim(0, 15)
plt.title(j)
plt.xlabel('Date')
plt.grid()
ax1.legend(loc=2)
ax2.legend(loc=1)
fig.set_size_inches(18.5, 10.5)

ax1.set_xlabel('Date')
ax1.set_ylabel('Error (Real - Predicted)')
ax2.set_ylabel('Price (US $)')
#plt.savefig('cumulative_error_20_countries_XGB_dpi300.jpeg', dpi=300)
# Out:
# Text(0, 0.5, 'Price (US $)')

# %%
## Check for the directory and output the df_global dataframe.
if os.path.exists(os.path.join(os.getcwd(), "model_predictions")) is False:
    os.mkdir(os.path.join(os.getcwd(), "model_predictions"))
df_global_high.to_csv(os.path.join(os.getcwd(), "model_predictions", "Rein_nn_predictions_high.csv"))
df_global_mid.to_csv(os.path.join(os.getcwd(), "model_predictions", "Rein_nn_predictions_mid.csv"))
df_global_low.to_csv(os.path.join(os.getcwd(), "model_predictions", "Rein_nn_predictions_low.csv"))

# %%
plt.style.use("ggplot")

# %%
## Plot deaths vs predicted.
plt.figure(figsize=(8, 8))
plt.scatter(df1.GOLDAMGBDollarD228NLBM, df1.gold_pred)
plt.plot(df1.GOLDAMGBDollarD228NLBM, df1.GOLDAMGBDollarD228NLBM, color="black", linestyle="--")
plt.xlabel("GOLDAMGBDollarD228NLBM")
plt.ylabel("predicted gold")
plt.show()

# %%
## Plot deaths vs predicted.
plt.figure(figsize=(8, 8))
plt.scatter(df_global.GOLDAMGBDollarD228NLBM, df_global.gold_pred)
plt.plot(df_global.GOLDAMGBDollarD228NLBM, df_global.GOLDAMGBDollarD228NLBM, color="black", linestyle="--")
plt.xlabel("GOLDAMGBDollarD228NLBM")
plt.ylabel("predicted gold")
plt.show()

# %%
plt.rcdefaults()
